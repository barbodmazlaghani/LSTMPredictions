# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp "/content/gdrive/My Drive/DataAugumentation.zip" .
#ADDED NEW SOURCE
# !cp "/content/gdrive/MyDrive/data_aug(3_slices_with_repeated)_cluster_5_ehsan_0.5.zip" .
# !unzip -qq DataAugumentation.zip
# !unzip -qq data_aug_3_slices_with_repeated_cluster_5.zip
# !rm DataAugumentation.zip
# !rm data_aug_3_slices_with_repeated_cluster_5.zip
data_path = 'DataAugumentation'
# Out:
# unzip:  cannot find or open DataAugumentation.zip, DataAugumentation.zip.zip or DataAugumentation.zip.ZIP.
# unzip:  cannot find or open data_aug_3_slices_with_repeated_cluster_5.zip, data_aug_3_slices_with_repeated_cluster_5.zip.zip or data_aug_3_slices_with_repeated_cluster_5.zip.ZIP.
# rm: cannot remove 'DataAugumentation.zip': No such file or directory
# rm: cannot remove 'data_aug_3_slices_with_repeated_cluster_5.zip': No such file or directory

# %%
# !unzip -qq '/content/data_aug(3_slices_with_repeated)_cluster_5_ehsan_0.5.zip'

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
import joblib

SEQUENCE_LENGTH = 200  # Updated sequence length
BATCH_SIZE = 64
EPOCHS = 250
LEARNING_RATE = 1e-5
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)

# Data processing function
def process_file(file_path):
    df = pd.read_csv(file_path)
    if df.shape[0]>=600:
      # print(df)
      df['Time'] = df['Time'] - df['Time'].iloc[0]

      df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
      df['Acceleration'] = df['Speed'].diff().fillna(0)
      df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})

      # Selecting features and target
      features = df[['Adjusted_gear_position', 'Speed', 'slope', 'Acceleration']]
      target = df['Momentary fuel consumption']


      return features.values, target.values
    else:
      return None, None

# Function to slice data into chunks and append to lists
def slice_and_append(features, target, sequence_length, X_list, y_list):
    num_chunks = len(features) // sequence_length  # Should be 12 for your case

    for i in range(num_chunks):
        start_idx = i * sequence_length
        end_idx = start_idx + sequence_length

        # Slicing the features and target arrays
        sliced_features = features[start_idx:end_idx]
        sliced_target = target[start_idx:end_idx]

        # Append the sliced features and target to the respective lists
        X_list.append(sliced_features)
        y_list.append(sliced_target)

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_original = []
y_original = []
X_augmented = []
y_augmented = []

base_folder_path = '/content/'

# Process the data and slice into smaller DataFrames
for i in range(6):
    if i == 5:
        folder_path = os.path.join(base_folder_path, f'data_aug(3_slices_with_repeated)_cluster_{i}')
        for filename in os.listdir(folder_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(folder_path, filename)

                features, target = process_file(file_path)
                if features is not None and target is not None:
                  slices = filename.split('_')
                  is_original_trip = slices[2] == slices[6] and slices[6] == slices[10]

                  if is_original_trip:
                      slice_and_append(features, target, SEQUENCE_LENGTH, X_original, y_original)
                  else:
                      slice_and_append(features, target, SEQUENCE_LENGTH, X_augmented, y_augmented)
# Out:
# cuda
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-61a3fdd8a191> in <cell line: 66>()
#      71                 file_path = os.path.join(folder_path, filename)
#      72
# ---> 73                 features, target = process_file(file_path)
#      74                 if features is not None and target is not None:
#      75                   slices = filename.split('_')
#
# <ipython-input-140-61a3fdd8a191> in process_file(file_path)
#      25
#      26       df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
# ---> 27       df['Acceleration'] = df['Speed'].diff().fillna(0)
#      28       df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})
#      29
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7210                     )
#    7211
# -> 7212                 new_data = self._mgr.fillna(
#    7213                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    7214                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in fillna(self, value, limit, inplace, downcast)
#     171             limit = libalgos.validate_limit(None, limit=limit)
#     172
# --> 173         return self.apply_with_block(
#     174             "fillna",
#     175             value=value,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     352                 applied = b.apply(f, **kwargs)
#     353             else:
# --> 354                 applied = getattr(b, f)(**kwargs)
#     355             result_blocks = extend_blocks(applied, result_blocks)
#     356
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast, using_cow)
#    1423         #  different behavior in _maybe_downcast.
#    1424         return extend_blocks(
# -> 1425             [
#    1426                 blk._maybe_downcast([blk], downcast=downcast, using_cow=using_cow)
#    1427                 for blk in nbs
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#    1424         return extend_blocks(
#    1425             [
# -> 1426                 blk._maybe_downcast([blk], downcast=downcast, using_cow=using_cow)
#    1427                 for blk in nbs
#    1428             ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in _maybe_downcast(self, blocks, downcast, using_cow)
#     502             return blocks
#     503
# --> 504         if self.dtype == _dtype_obj:
#     505             # TODO: does it matter that self.dtype might not match blocks[i].dtype?
#     506             # GH#44241 We downcast regardless of the argument;
#
# KeyboardInterrupt:

# %%
# Function to pad or truncate sequences
def pad_or_truncate(sequence, length):
    if len(sequence) > length:
        return sequence[:length]
    elif len(sequence) < length:
        return np.pad(sequence, ((0, length - len(sequence)), (0, 0)), mode='constant')
    else:
        return sequence

# %%
# Apply padding/truncating to ensure consistent sequence length
X_original = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_original]
y_original = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_original]
X_augmented = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_augmented]
y_augmented = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_augmented]

# %%
# Convert data to PyTorch tensors
try:
    X_original = torch.tensor(np.array(X_original), dtype=torch.float32).to(DEVICE)
    y_original = torch.tensor(np.array(y_original), dtype=torch.float32).to(DEVICE)
    X_augmented = torch.tensor(np.array(X_augmented), dtype=torch.float32).to(DEVICE)
    y_augmented = torch.tensor(np.array(y_augmented), dtype=torch.float32).to(DEVICE)
except Exception as e:
    print(f"Error during tensor conversion: {e}")
    print(f"Shapes: X_original - {np.array(X_original).shape}, y_original - {np.array(y_original).shape}")
    print(f"Shapes: X_augmented - {np.array(X_augmented).shape}, y_augmented - {np.array(y_augmented).shape}")
    raise

# %%
# Split into training and test sets
# num_test = int(0.2 * len(X_original))
# X_test = X_original[:num_test]
# y_test = y_original[:num_test]
# X_train = torch.cat([X_original[num_test:], X_augmented])
# y_train = torch.cat([y_original[num_test:], y_augmented])


X_train = torch.cat([X_original, X_augmented])
y_train = torch.cat([y_original, y_augmented])
# X_train = X_original[num_test:]
# y_train = y_original[num_test:]

# %%
X_train
# Out:
# tensor([[[ 4.0000, 68.0000,  3.8217,  0.0000],
#          [ 4.0000, 67.0000,  3.8217, -1.0000],
#          [ 4.0000, 67.0000,  3.8217,  0.0000],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000]],
#
#         [[ 0.0000,  0.0000, -1.3514,  0.0000],
#          [ 0.0000,  0.0000, -1.3514,  0.0000],
#          [ 0.0000,  0.0000, -1.3514,  0.0000],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000]],
#
#         [[ 4.0000, 66.0000, -1.3321,  0.0000],
#          [ 4.0000, 67.0000, -1.3321,  1.0000],
#          [ 4.0000, 67.0000, -1.3321,  0.0000],
#          ...,
#          [ 0.0000,  0.0000,  3.1250,  0.0000],
#          [ 0.0000,  0.0000,  3.1250,  0.0000],
#          [ 0.0000,  0.0000,  3.1250,  0.0000]],
#
#         ...,
#
#         [[ 0.0000,  0.0000, -1.3514,  0.0000],
#          [ 0.0000,  0.0000, -1.3514,  0.0000],
#          [ 0.0000,  0.0000, -1.3514,  0.0000],
#          ...,
#          [ 0.0000,  0.0000,  3.1250,  0.0000],
#          [ 0.0000,  0.0000,  3.1250,  0.0000],
#          [ 0.0000,  0.0000,  3.1250,  0.0000]],
#
#         [[ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          ...,
#          [ 3.0000, 22.0000,  2.0202, -1.0000],
#          [ 3.0000, 20.0000,  2.0202, -2.0000],
#          [ 3.0000, 18.0000,  2.0202, -2.0000]],
#
#         [[ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000],
#          ...,
#          [ 3.0000, 38.0000,  1.2987,  0.0000],
#          [ 3.0000, 37.0000,  1.2987, -1.0000],
#          [ 3.0000, 37.0000,  1.2987,  0.0000]]], device='cuda:0')

# %%
# Convert the min and max values to tensors
min_val_x = torch.tensor([0, 0, -10, -10], dtype=torch.float32).to(DEVICE)
max_val_x = torch.tensor([6, 150, 10, 10], dtype=torch.float32).to(DEVICE)

min_val_y = torch.tensor([0], dtype=torch.float32).to(DEVICE)
max_val_y = torch.tensor([10000], dtype=torch.float32).to(DEVICE)

# Custom normalization function for X
def custom_normalize_X(data, min_vals, max_vals):
    for i in range(data.shape[-1]):
        data[:, :, i] = (data[:, :, i] - min_vals[i]) / (max_vals[i] - min_vals[i])
    return data

# Custom normalization function for y
def custom_normalize_y(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# Normalize X_train and X_test
X_train_normalized = custom_normalize_X(X_train, min_val_x, max_val_x)
# X_test_normalized = custom_normalize_X(X_test, min_val_x, max_val_x)

# Normalize y_train and y_test
y_train_normalized = custom_normalize_y(y_train, min_val_y, max_val_y)
# y_test_normalized = custom_normalize_y(y_test, min_val_y, max_val_y)

# %%
X_train_normalized
# Out:
# tensor([[[0.6667, 0.4533, 0.6911, 0.5000],
#          [0.6667, 0.4467, 0.6911, 0.4500],
#          [0.6667, 0.4467, 0.6911, 0.5000],
#          ...,
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000]],
#
#         [[0.0000, 0.0000, 0.4324, 0.5000],
#          [0.0000, 0.0000, 0.4324, 0.5000],
#          [0.0000, 0.0000, 0.4324, 0.5000],
#          ...,
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000]],
#
#         [[0.6667, 0.4400, 0.4334, 0.5000],
#          [0.6667, 0.4467, 0.4334, 0.5500],
#          [0.6667, 0.4467, 0.4334, 0.5000],
#          ...,
#          [0.0000, 0.0000, 0.6562, 0.5000],
#          [0.0000, 0.0000, 0.6562, 0.5000],
#          [0.0000, 0.0000, 0.6562, 0.5000]],
#
#         ...,
#
#         [[0.0000, 0.0000, 0.4324, 0.5000],
#          [0.0000, 0.0000, 0.4324, 0.5000],
#          [0.0000, 0.0000, 0.4324, 0.5000],
#          ...,
#          [0.0000, 0.0000, 0.6562, 0.5000],
#          [0.0000, 0.0000, 0.6562, 0.5000],
#          [0.0000, 0.0000, 0.6562, 0.5000]],
#
#         [[0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          ...,
#          [0.5000, 0.1467, 0.6010, 0.4500],
#          [0.5000, 0.1333, 0.6010, 0.4000],
#          [0.5000, 0.1200, 0.6010, 0.4000]],
#
#         [[0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000, 0.5000],
#          ...,
#          [0.5000, 0.2533, 0.5649, 0.5000],
#          [0.5000, 0.2467, 0.5649, 0.4500],
#          [0.5000, 0.2467, 0.5649, 0.5000]]], device='cuda:0')

# %%
# Define the PyTorch model
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)

        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# %%
# class FuelConsumptionModel(nn.Module):
#     def __init__(self, input_size):
#         super(FuelConsumptionModel, self).__init__()
#         self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
#         self.dropout1 = nn.Dropout(0.2)
#         self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
#         self.dropout2 = nn.Dropout(0.2)
#         self.lstm3 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
#         self.dropout3 = nn.Dropout(0.2)
#         self.lstm4 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
#         self.dropout4 = nn.Dropout(0.2)
#         self.dense = nn.Linear(64, 1)

#     def forward(self, x):
#         x, _ = self.lstm1(x)
#         x = self.dropout1(x)
#         x, _ = self.lstm2(x)
#         x = self.dropout2(x)
#         x, _ = self.lstm3(x)
#         x = self.dropout3(x)
#         x, _ = self.lstm4(x)
#         x = self.dropout4(x)
#         x = self.dense(x)
#         return x

# %%
# Instantiate the model, define the loss function and the optimizer
model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
criterion = nn.L1Loss()
weight_decay = 1e-4  # L2 regularization factor
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=weight_decay)

# %%
# Assume 80% of the data is used for training and 20% for validation
train_size = int(0.8 * len(X_train_normalized))
val_size = len(X_train_normalized) - train_size

# Split the data while preserving the order
X_train_split = X_train_normalized[:train_size]
y_train_split = y_train_normalized[:train_size]

X_val_split = X_train_normalized[train_size:]
y_val_split = y_train_normalized[train_size:]



# BATCH_SIZE = 96
# # Create DataLoader for training and validation sets
# train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
# val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR  # Importing StepLR for learning rate decay

# Assuming `FuelConsumptionModel`, `X_train_normalized`, `train_loader`, `val_loader`, `DEVICE`, and `EPOCHS` are defined

# Choose a single loss function to use for all experiments
criterion = nn.L1Loss()  # You can change this to your preferred loss function

# Define weight decay values and initial learning rates for decay schedules
weight_decay_values = 1e-5
initial_learning_rates = [1e-4]  # Two starting learning rates

# Initialize variables to track the best parameters
best_weight_decay = None
best_initial_lr = None
best_model_weights = None
best_val_loss = float('inf')

ini_batches = [64]
# Loop over all combinations of initial learning rates and weight decay values

BATCH_SIZE = 64
# Create DataLoader for training and validation sets
train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

for init_lr in initial_learning_rates:
    # Initialize model, criterion, and optimizer for each combination
    model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=weight_decay_values)
    scheduler = StepLR(optimizer, step_size=50, gamma=0.5)  # Decay LR by 0.5 every 50 epochs

    # Early stopping parameters
    patience = 10  # Number of epochs to wait before stopping if no improvement
    best_loss = float('inf')  # Initialize best loss to infinity
    epochs_without_improvement = 0  # Counter for epochs without improvement

    # Training loop with early stopping
    model.train()
    for epoch in range(EPOCHS):
        running_loss = 0.0
        model.train()  # Ensure model is in training mode

        # Training phase
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Calculate average loss for the epoch
        avg_training_loss = running_loss / len(train_loader)

        # Validation phase
        model.eval()  # Switch to evaluation mode
        val_running_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:  # Assume you have a validation DataLoader `val_loader`
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
                outputs = model(inputs)
                val_loss = criterion(outputs, targets)
                val_running_loss += val_loss.item()

        avg_val_loss = val_running_loss / len(val_loader)

        current_lr = optimizer.param_groups[0]['lr']
        print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.6f}")

        # print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.4f}    Init LR: {init_lr:.0e}  WD: {wd:.0e}")

        # Adjust the learning rate
        scheduler.step()

        # Early stopping check
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
            if epochs_without_improvement >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

        # Save the model for the current combination
        model_filename = f'best_fuel_consumption_model.pth'
        torch.save(model.state_dict(), model_filename)


print(f"Saved model: {model_filename}")
# Out:
# Epoch [1/250] ---- Training Loss: 0.0406 ---- Validation Loss: 0.027409
# Epoch [2/250] ---- Training Loss: 0.0299 ---- Validation Loss: 0.025059
# Epoch [3/250] ---- Training Loss: 0.0266 ---- Validation Loss: 0.024340
# Epoch [4/250] ---- Training Loss: 0.0254 ---- Validation Loss: 0.023754
# Epoch [5/250] ---- Training Loss: 0.0245 ---- Validation Loss: 0.023245
# Epoch [6/250] ---- Training Loss: 0.0238 ---- Validation Loss: 0.022640
# Epoch [7/250] ---- Training Loss: 0.0232 ---- Validation Loss: 0.022103
# Epoch [8/250] ---- Training Loss: 0.0228 ---- Validation Loss: 0.021914
# Epoch [9/250] ---- Training Loss: 0.0225 ---- Validation Loss: 0.021479
# Epoch [10/250] ---- Training Loss: 0.0221 ---- Validation Loss: 0.021117
# Epoch [11/250] ---- Training Loss: 0.0218 ---- Validation Loss: 0.020660
# Epoch [12/250] ---- Training Loss: 0.0213 ---- Validation Loss: 0.020212
# Epoch [13/250] ---- Training Loss: 0.0209 ---- Validation Loss: 0.019864
# Epoch [14/250] ---- Training Loss: 0.0204 ---- Validation Loss: 0.019233
# Epoch [15/250] ---- Training Loss: 0.0200 ---- Validation Loss: 0.018651
# Epoch [16/250] ---- Training Loss: 0.0194 ---- Validation Loss: 0.018171
# Epoch [17/250] ---- Training Loss: 0.0189 ---- Validation Loss: 0.017722
# Epoch [18/250] ---- Training Loss: 0.0184 ---- Validation Loss: 0.017259
# Epoch [19/250] ---- Training Loss: 0.0180 ---- Validation Loss: 0.016755
# Epoch [20/250] ---- Training Loss: 0.0176 ---- Validation Loss: 0.016352
# Epoch [21/250] ---- Training Loss: 0.0171 ---- Validation Loss: 0.016081
# Epoch [22/250] ---- Training Loss: 0.0168 ---- Validation Loss: 0.015574
# Epoch [23/250] ---- Training Loss: 0.0165 ---- Validation Loss: 0.015322
# Epoch [24/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.015073
# Epoch [25/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014928
# Epoch [26/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014709
# Epoch [27/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014520
# Epoch [28/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014389
# Epoch [29/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.014381
# Epoch [30/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.014190
# Epoch [31/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.014186
# Epoch [32/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.014007
# Epoch [33/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013887
# Epoch [34/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013935
# Epoch [35/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013846
# Epoch [36/250] ---- Training Loss: 0.0146 ---- Validation Loss: 0.013693
# Epoch [37/250] ---- Training Loss: 0.0145 ---- Validation Loss: 0.013612
# Epoch [38/250] ---- Training Loss: 0.0144 ---- Validation Loss: 0.013561
# Epoch [39/250] ---- Training Loss: 0.0144 ---- Validation Loss: 0.013621
# Epoch [40/250] ---- Training Loss: 0.0143 ---- Validation Loss: 0.013460
# Epoch [41/250] ---- Training Loss: 0.0143 ---- Validation Loss: 0.013628
# Epoch [42/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.013456
# Epoch [43/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.013339
# Epoch [44/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.013280
# Epoch [45/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.013286
# Epoch [46/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013367
# Epoch [47/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013273
# Epoch [48/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013167
# Epoch [49/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.013197
# Epoch [50/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.013104
# Epoch [51/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.013073
# Epoch [52/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.013061
# Epoch [53/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.013054
# Epoch [54/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.013029
# Epoch [55/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.013003
# Epoch [56/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.012999
# Epoch [57/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012989
# Epoch [58/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012986
# Epoch [59/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012946
# Epoch [60/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012919
# Epoch [61/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012890
# Epoch [62/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012900
# Epoch [63/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012859
# Epoch [64/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012838
# Epoch [65/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012823
# Epoch [66/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012841
# Epoch [67/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012777
# Epoch [68/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012800
# Epoch [69/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012729
# Epoch [70/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012712
# Epoch [71/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012727
# Epoch [72/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012707
# Epoch [73/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012646
# Epoch [74/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012607
# Epoch [75/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012571
# Epoch [76/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012540
# Epoch [77/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012495
# Epoch [78/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012442
# Epoch [79/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012412
# Epoch [80/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012472
# Epoch [81/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012399
# Epoch [82/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012348
# Epoch [83/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012311
# Epoch [84/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012259
# Epoch [85/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012223
# Epoch [86/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012198
# Epoch [87/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012198
# Epoch [88/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012161
# Epoch [89/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012240
# Epoch [90/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012136
# Epoch [91/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012092
# Epoch [92/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012104
# Epoch [93/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.012062
# Epoch [94/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.012038
# Epoch [96/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.012033
# Epoch [97/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011991
# Epoch [98/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.012015
# Epoch [99/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.012031
# Epoch [100/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011948
# Epoch [101/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011926
# Epoch [102/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011939
# Epoch [103/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011910
# Epoch [104/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011901
# Epoch [105/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011885
# Epoch [106/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011884
# Epoch [107/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011903
# Epoch [108/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011869
# Epoch [109/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011856
# Epoch [110/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011852
# Epoch [111/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011836
# Epoch [112/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011842
# Epoch [113/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011820
# Epoch [114/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011836
# Epoch [115/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011831
# Epoch [116/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011798
# Epoch [117/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011791
# Epoch [118/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011779
# Epoch [119/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011772
# Epoch [120/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011777
# Epoch [121/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011764
# Epoch [122/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011769
# Epoch [123/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011756
# Epoch [124/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011735
# Epoch [125/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011735
# Epoch [126/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011715
# Epoch [127/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011698
# Epoch [128/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011719
# Epoch [129/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011756
# Epoch [130/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011678
# Epoch [131/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011693
# Epoch [132/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011681
# Epoch [133/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011670
# Epoch [134/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011658
# Epoch [135/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.011678
# Epoch [136/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011631
# Epoch [137/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011632
# Epoch [138/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011619
# Epoch [139/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011623
# Epoch [140/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011609
# Epoch [141/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011602
# Epoch [142/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011601
# Epoch [143/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011606
# Epoch [144/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011584
# Epoch [145/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011580
# Epoch [146/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011573
# Epoch [147/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011578
# Epoch [148/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011550
# Epoch [149/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011552
# Epoch [150/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.011550
# Epoch [151/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011532
# Epoch [152/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011536
# Epoch [153/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011530
# Epoch [154/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011517
# Epoch [155/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011521
# Epoch [156/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011521
# Epoch [157/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011509
# Epoch [158/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011508
# Epoch [159/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011503
# Epoch [160/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011495
# Epoch [161/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011496
# Epoch [162/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011493
# Epoch [163/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011494
# Epoch [164/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011490
# Epoch [165/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011493
# Epoch [166/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011484
# Epoch [167/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011478
# Epoch [168/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011471
# Epoch [169/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011477
# Epoch [170/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011465
# Epoch [171/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011459
# Epoch [172/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011454
# Epoch [173/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011462
# Epoch [174/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011456
# Epoch [175/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011451
# Epoch [176/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011460
# Epoch [177/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.011437
# Epoch [178/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011439
# Epoch [179/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011443
# Epoch [180/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011445
# Epoch [181/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011425
# Epoch [182/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011423
# Epoch [183/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011424
# Epoch [184/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011419
# Epoch [185/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011431
# Epoch [186/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011416
# Epoch [187/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011433
# Epoch [188/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011403
# Epoch [189/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011409
# Epoch [190/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011409
# Epoch [191/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011422
# Epoch [192/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011395
# Epoch [193/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011385
# Epoch [194/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011384
# Epoch [195/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011377
# Epoch [196/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011378
# Epoch [197/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011383
# Epoch [198/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011370
# Epoch [199/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011365
# Epoch [200/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011377
# Epoch [201/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011362
# Epoch [202/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011368
# Epoch [203/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011361
# Epoch [204/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011360
# Epoch [205/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011352
# Epoch [206/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011353
# Epoch [207/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011353
# Epoch [208/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011353
# Epoch [209/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011354
# Epoch [210/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011348
# Epoch [211/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011350
# Epoch [212/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011344
# Epoch [213/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.011343
# Epoch [214/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011343
# Epoch [215/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011339
# Epoch [216/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011340
# Epoch [217/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011335
# Epoch [218/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011330
# Epoch [219/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011337
# Epoch [220/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011332
# Epoch [221/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011335
# Epoch [222/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011328
# Epoch [223/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011331
# Epoch [224/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011327
# Epoch [225/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011323
# Epoch [226/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011326
# Epoch [227/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011318
# Epoch [228/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011316
# Epoch [229/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011317
# Epoch [230/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011316
# Epoch [231/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011313
# Epoch [232/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011311
# Epoch [233/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011312
# Epoch [234/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011326
# Epoch [235/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011316
# Epoch [236/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011313
# Epoch [237/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011308
# Epoch [238/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011311
# Epoch [239/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011304
# Epoch [240/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011297
# Epoch [241/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011303
# Epoch [242/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011309
# Epoch [243/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011300
# Epoch [244/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011291
# Epoch [245/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011292
# Epoch [246/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011289
# Epoch [247/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011291
# Epoch [248/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011284
# Epoch [249/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011291
# Epoch [250/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.011283
# Saved model: best_fuel_consumption_model.pth

# %% [markdown]
# #test

# %% [markdown]
# #Test with all saved model

# %%
# Out:
# Testing model: best_fuel_consumption_model_batch32_l200_without_acc
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch32_l200_without_acc.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch32_l200_without_acc.csv
# Testing model: best_fuel_consumption_model_batch45_l200_without_acc
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200_without_acc.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200_without_acc.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 200  # Updated sequence length
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)

        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)

        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['Time'] - df['Time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip fuel consumption'] - df['Trip fuel consumption'].iloc[0]
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    features = df[['Engine speed', 'Speed', 'slope', 'Acceleration']]
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    df['Adjusted_gear_position'] = df['gear'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [6, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 10000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values], sequence_length=remainder)
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 10000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Save plot using model name
    directory, filename = os.path.split(input_file)
    plot_filename = os.path.join(f'{os.path.splitext(filename)[0]}_{model_name}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name
    results_df = pd.DataFrame({
        'Speed': features["Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_ne.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/NEDC_1000_slope_added_with_gear.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model
# <ipython-input-139-1ccfce366f9d>:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: NEDC_1000_slope_added_with_gear_best_fuel_consumption_model.png
# CSV saved as: /content/NEDC_1000_slope_added_with_gear_ne.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 200  # Updated sequence length
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'  # Base directory to save plots and CSVs
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Ensure the base save directory exists
os.makedirs(PLOT_SAVE_DIR, exist_ok=True)

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)

        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)

        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df = df.iloc[::2].reset_index(drop=True)
    df['Time'] = df['time'] - df['time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip_fuel_consumption'] - df['Trip_fuel_consumption'].iloc[0]
    df['Acceleration'] = df['Vehicle_Speed'].diff().fillna(0)
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})
    print(df['Momentary fuel consumption'].max())
    print(df.shape[0])

    print(df.shape[0])
    print(df['Momentary fuel consumption'].max())
    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Vehicle_Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [6, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values], sequence_length=remainder)
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Create model-specific directory
    model_save_dir = os.path.join(PLOT_SAVE_DIR, model_name)
    os.makedirs(model_save_dir, exist_ok=True)

    # Save plot using model name in the designated directory
    plot_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}_all.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name in the designated directory
    results_df = pd.DataFrame({
        'Speed': features["Vehicle_Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/output_file_ehsan_1_4.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model
# 3263.125
# 300
# 300
# 3263.125
# <ipython-input-150-d81f789f24a9>:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4_all.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4.csv

# %%
# !rm -r '/content/predicted_vs_actual_plots'

# %%
# !zip -r /content/predicted_vs_actual_plots.zip /content/predicted_vs_actual_plots
# Out:
#   adding: content/predicted_vs_actual_plots/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_1_slope_added.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/6_1_slope_added_all.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_2_slope_added_all.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4_all.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/2_1_slope_added_all.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_1_slope_added_all.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/6_1_slope_added.csv (deflated 52%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_2.csv (deflated 59%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/2_1_slope_added.csv (deflated 54%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_2_slope_added.csv (deflated 62%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_2_all.png (deflated 9%)

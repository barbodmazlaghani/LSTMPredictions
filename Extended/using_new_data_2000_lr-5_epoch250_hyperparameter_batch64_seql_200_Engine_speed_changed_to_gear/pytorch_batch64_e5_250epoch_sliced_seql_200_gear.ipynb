# %%
from google.colab import drive
drive.mount('/content/gdrive')


# !cp "/content/gdrive/My Drive/DataAugumentation.zip" .
#ADDED NEW SOURCE
# !cp "/content/gdrive/My Drive/data_aug(3_slices_with_repeated)_acceleration_full_data_20000.zip" .
# !unzip -qq DataAugumentation.zip
# !unzip -qq data_aug_3_slices_with_repeated_cluster_5.zip
# !rm DataAugumentation.zip
# !rm data_aug_3_slices_with_repeated_cluster_5.zip
data_path = 'DataAugumentation'
# Out:
# Mounted at /content/gdrive
# unzip:  cannot find or open DataAugumentation.zip, DataAugumentation.zip.zip or DataAugumentation.zip.ZIP.
# unzip:  cannot find or open data_aug_3_slices_with_repeated_cluster_5.zip, data_aug_3_slices_with_repeated_cluster_5.zip.zip or data_aug_3_slices_with_repeated_cluster_5.zip.ZIP.
# rm: cannot remove 'DataAugumentation.zip': No such file or directory
# rm: cannot remove 'data_aug_3_slices_with_repeated_cluster_5.zip': No such file or directory

# %%
# !unzip -qq '/content/data_aug(3_slices_with_repeated)_acceleration_full_data_20000.zip'

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
import joblib

SEQUENCE_LENGTH = 200  # Updated sequence length
BATCH_SIZE = 64
EPOCHS = 250
LEARNING_RATE = 1e-5
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)

# Data processing function
def process_file(file_path):
    df = pd.read_csv(file_path)
    # print(df)
    df['Time'] = df['Time'] - df['Time'].iloc[0]

    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']


    return features.values, target.values

# Function to slice data into chunks and append to lists
def slice_and_append(features, target, sequence_length, X_list, y_list):
    num_chunks = len(features) // sequence_length  # Should be 12 for your case

    for i in range(num_chunks):
        start_idx = i * sequence_length
        end_idx = start_idx + sequence_length

        # Slicing the features and target arrays
        sliced_features = features[start_idx:end_idx]
        sliced_target = target[start_idx:end_idx]

        # Append the sliced features and target to the respective lists
        X_list.append(sliced_features)
        y_list.append(sliced_target)

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_original = []
y_original = []
X_augmented = []
y_augmented = []

base_folder_path = '/content/'

# Process the data and slice into smaller DataFrames
for i in range(6):
    if i == 5:
        folder_path = os.path.join(base_folder_path, f'data_aug(3_slices_with_repeated)_cluster_{i}')
        for filename in os.listdir(folder_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(folder_path, filename)
                features, target = process_file(file_path)

                slices = filename.split('_')
                is_original_trip = slices[2] == slices[6] and slices[6] == slices[10]

                if is_original_trip:
                    slice_and_append(features, target, SEQUENCE_LENGTH, X_original, y_original)
                else:
                    slice_and_append(features, target, SEQUENCE_LENGTH, X_augmented, y_augmented)
# Out:
# cuda

# %%
# Function to pad or truncate sequences
def pad_or_truncate(sequence, length):
    if len(sequence) > length:
        return sequence[:length]
    elif len(sequence) < length:
        return np.pad(sequence, ((0, length - len(sequence)), (0, 0)), mode='constant')
    else:
        return sequence

# %%
# Apply padding/truncating to ensure consistent sequence length
X_original = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_original]
y_original = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_original]
X_augmented = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_augmented]
y_augmented = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_augmented]

# %%
# Convert data to PyTorch tensors
try:
    X_original = torch.tensor(np.array(X_original), dtype=torch.float32).to(DEVICE)
    y_original = torch.tensor(np.array(y_original), dtype=torch.float32).to(DEVICE)
    X_augmented = torch.tensor(np.array(X_augmented), dtype=torch.float32).to(DEVICE)
    y_augmented = torch.tensor(np.array(y_augmented), dtype=torch.float32).to(DEVICE)
except Exception as e:
    print(f"Error during tensor conversion: {e}")
    print(f"Shapes: X_original - {np.array(X_original).shape}, y_original - {np.array(y_original).shape}")
    print(f"Shapes: X_augmented - {np.array(X_augmented).shape}, y_augmented - {np.array(y_augmented).shape}")
    raise

# %%
# Split into training and test sets
# num_test = int(0.2 * len(X_original))
# X_test = X_original[:num_test]
# y_test = y_original[:num_test]
# X_train = torch.cat([X_original[num_test:], X_augmented])
# y_train = torch.cat([y_original[num_test:], y_augmented])


X_train = torch.cat([X_original, X_augmented])
y_train = torch.cat([y_original, y_augmented])
# X_train = X_original[num_test:]
# y_train = y_original[num_test:]

# %%
# Convert the min and max values to tensors
min_val_x = torch.tensor([0, 0, -10, -10], dtype=torch.float32).to(DEVICE)
max_val_x = torch.tensor([6, 150, 10, 10], dtype=torch.float32).to(DEVICE)

min_val_y = torch.tensor([0], dtype=torch.float32).to(DEVICE)
max_val_y = torch.tensor([20000], dtype=torch.float32).to(DEVICE)

# Custom normalization function for X
def custom_normalize_X(data, min_vals, max_vals):
    for i in range(data.shape[-1]):
        data[:, :, i] = (data[:, :, i] - min_vals[i]) / (max_vals[i] - min_vals[i])
    return data

# Custom normalization function for y
def custom_normalize_y(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# Normalize X_train and X_test
X_train_normalized = custom_normalize_X(X_train, min_val_x, max_val_x)
# X_test_normalized = custom_normalize_X(X_test, min_val_x, max_val_x)

# Normalize y_train and y_test
y_train_normalized = custom_normalize_y(y_train, min_val_y, max_val_y)
# y_test_normalized = custom_normalize_y(y_test, min_val_y, max_val_y)

# %%
# Define the PyTorch model
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# %%
# Instantiate the model, define the loss function and the optimizer
model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
criterion = nn.L1Loss()
weight_decay = 1e-4  # L2 regularization factor
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=weight_decay)

# %%
# Assume 80% of the data is used for training and 20% for validation
train_size = int(0.8 * len(X_train_normalized))
val_size = len(X_train_normalized) - train_size

# Split the data while preserving the order
X_train_split = X_train_normalized[:train_size]
y_train_split = y_train_normalized[:train_size]

X_val_split = X_train_normalized[train_size:]
y_val_split = y_train_normalized[train_size:]



# BATCH_SIZE = 96
# # Create DataLoader for training and validation sets
# train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
# val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR  # Importing StepLR for learning rate decay

# Assuming `FuelConsumptionModel`, `X_train_normalized`, `train_loader`, `val_loader`, `DEVICE`, and `EPOCHS` are defined

# Choose a single loss function to use for all experiments
criterion = nn.L1Loss()  # You can change this to your preferred loss function

# Define weight decay values and initial learning rates for decay schedules
weight_decay_values = 1e-5
initial_learning_rates = [1e-4]  # Two starting learning rates

# Initialize variables to track the best parameters
best_weight_decay = None
best_initial_lr = None
best_model_weights = None
best_val_loss = float('inf')

ini_batches = [64]
# Loop over all combinations of initial learning rates and weight decay values

BATCH_SIZE = 64
# Create DataLoader for training and validation sets
train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

for init_lr in initial_learning_rates:
    # Initialize model, criterion, and optimizer for each combination
    model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=weight_decay_values)
    scheduler = StepLR(optimizer, step_size=50, gamma=0.5)  # Decay LR by 0.5 every 50 epochs

    # Early stopping parameters
    patience = 10  # Number of epochs to wait before stopping if no improvement
    best_loss = float('inf')  # Initialize best loss to infinity
    epochs_without_improvement = 0  # Counter for epochs without improvement

    # Training loop with early stopping
    model.train()
    for epoch in range(EPOCHS):
        running_loss = 0.0
        model.train()  # Ensure model is in training mode

        # Training phase
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Calculate average loss for the epoch
        avg_training_loss = running_loss / len(train_loader)

        # Validation phase
        model.eval()  # Switch to evaluation mode
        val_running_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:  # Assume you have a validation DataLoader `val_loader`
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
                outputs = model(inputs)
                val_loss = criterion(outputs, targets)
                val_running_loss += val_loss.item()

        avg_val_loss = val_running_loss / len(val_loader)

        current_lr = optimizer.param_groups[0]['lr']
        print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.6f}")

        # print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.4f}    Init LR: {init_lr:.0e}  WD: {wd:.0e}")

        # Adjust the learning rate
        scheduler.step()

        # Early stopping check
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
            if epochs_without_improvement >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

        # Save the model for the current combination
        model_filename = f'best_fuel_consumption_model.pth'
        torch.save(model.state_dict(), model_filename)


print(f"Saved model: {model_filename}")
# Out:
# Epoch [1/250] ---- Training Loss: 0.0383 ---- Validation Loss: 0.033063
# Saved model: best_fuel_consumption_model.pth
# Epoch [2/250] ---- Training Loss: 0.0320 ---- Validation Loss: 0.029787
# Saved model: best_fuel_consumption_model.pth
# Epoch [3/250] ---- Training Loss: 0.0293 ---- Validation Loss: 0.026517
# Saved model: best_fuel_consumption_model.pth
# Epoch [4/250] ---- Training Loss: 0.0260 ---- Validation Loss: 0.023138
# Saved model: best_fuel_consumption_model.pth
# Epoch [5/250] ---- Training Loss: 0.0233 ---- Validation Loss: 0.021167
# Saved model: best_fuel_consumption_model.pth
# Epoch [6/250] ---- Training Loss: 0.0217 ---- Validation Loss: 0.020014
# Saved model: best_fuel_consumption_model.pth
# Epoch [7/250] ---- Training Loss: 0.0208 ---- Validation Loss: 0.019299
# Saved model: best_fuel_consumption_model.pth
# Epoch [8/250] ---- Training Loss: 0.0202 ---- Validation Loss: 0.018784
# Saved model: best_fuel_consumption_model.pth
# Epoch [9/250] ---- Training Loss: 0.0197 ---- Validation Loss: 0.018319
# Saved model: best_fuel_consumption_model.pth
# Epoch [10/250] ---- Training Loss: 0.0193 ---- Validation Loss: 0.018065
# Saved model: best_fuel_consumption_model.pth
# Epoch [11/250] ---- Training Loss: 0.0190 ---- Validation Loss: 0.017828
# Saved model: best_fuel_consumption_model.pth
# Epoch [12/250] ---- Training Loss: 0.0188 ---- Validation Loss: 0.017590
# Saved model: best_fuel_consumption_model.pth
# Epoch [13/250] ---- Training Loss: 0.0186 ---- Validation Loss: 0.017444
# Saved model: best_fuel_consumption_model.pth
# Epoch [14/250] ---- Training Loss: 0.0185 ---- Validation Loss: 0.017327
# Saved model: best_fuel_consumption_model.pth
# Epoch [15/250] ---- Training Loss: 0.0184 ---- Validation Loss: 0.017221
# Saved model: best_fuel_consumption_model.pth
# Epoch [16/250] ---- Training Loss: 0.0183 ---- Validation Loss: 0.017309
# Saved model: best_fuel_consumption_model.pth
# Epoch [17/250] ---- Training Loss: 0.0182 ---- Validation Loss: 0.017078
# Saved model: best_fuel_consumption_model.pth
# Epoch [18/250] ---- Training Loss: 0.0181 ---- Validation Loss: 0.016945
# Saved model: best_fuel_consumption_model.pth
# Epoch [19/250] ---- Training Loss: 0.0180 ---- Validation Loss: 0.016858
# Saved model: best_fuel_consumption_model.pth
# Epoch [20/250] ---- Training Loss: 0.0179 ---- Validation Loss: 0.016800
# Saved model: best_fuel_consumption_model.pth
# Epoch [21/250] ---- Training Loss: 0.0179 ---- Validation Loss: 0.016726
# Saved model: best_fuel_consumption_model.pth
# Epoch [22/250] ---- Training Loss: 0.0178 ---- Validation Loss: 0.016681
# Saved model: best_fuel_consumption_model.pth
# Epoch [23/250] ---- Training Loss: 0.0177 ---- Validation Loss: 0.016608
# Saved model: best_fuel_consumption_model.pth
# Epoch [24/250] ---- Training Loss: 0.0177 ---- Validation Loss: 0.016636
# Saved model: best_fuel_consumption_model.pth
# Epoch [25/250] ---- Training Loss: 0.0176 ---- Validation Loss: 0.016557
# Saved model: best_fuel_consumption_model.pth
# Epoch [26/250] ---- Training Loss: 0.0176 ---- Validation Loss: 0.016438
# Saved model: best_fuel_consumption_model.pth
# Epoch [27/250] ---- Training Loss: 0.0175 ---- Validation Loss: 0.016376
# Saved model: best_fuel_consumption_model.pth
# Epoch [28/250] ---- Training Loss: 0.0174 ---- Validation Loss: 0.016287
# Saved model: best_fuel_consumption_model.pth
# Epoch [29/250] ---- Training Loss: 0.0174 ---- Validation Loss: 0.016247
# Saved model: best_fuel_consumption_model.pth
# Epoch [30/250] ---- Training Loss: 0.0173 ---- Validation Loss: 0.016213
# Saved model: best_fuel_consumption_model.pth
# Epoch [31/250] ---- Training Loss: 0.0173 ---- Validation Loss: 0.016135
# Saved model: best_fuel_consumption_model.pth
# Epoch [32/250] ---- Training Loss: 0.0172 ---- Validation Loss: 0.016088
# Saved model: best_fuel_consumption_model.pth
# Epoch [33/250] ---- Training Loss: 0.0172 ---- Validation Loss: 0.016052
# Saved model: best_fuel_consumption_model.pth
# Epoch [34/250] ---- Training Loss: 0.0171 ---- Validation Loss: 0.015938
# Saved model: best_fuel_consumption_model.pth
# Epoch [35/250] ---- Training Loss: 0.0171 ---- Validation Loss: 0.015894
# Saved model: best_fuel_consumption_model.pth
# Epoch [36/250] ---- Training Loss: 0.0170 ---- Validation Loss: 0.015886
# Saved model: best_fuel_consumption_model.pth
# Epoch [37/250] ---- Training Loss: 0.0170 ---- Validation Loss: 0.015780
# Saved model: best_fuel_consumption_model.pth
# Epoch [38/250] ---- Training Loss: 0.0169 ---- Validation Loss: 0.015768
# Saved model: best_fuel_consumption_model.pth
# Epoch [39/250] ---- Training Loss: 0.0169 ---- Validation Loss: 0.015693
# Saved model: best_fuel_consumption_model.pth
# Epoch [40/250] ---- Training Loss: 0.0168 ---- Validation Loss: 0.015620
# Saved model: best_fuel_consumption_model.pth
# Epoch [41/250] ---- Training Loss: 0.0168 ---- Validation Loss: 0.015588
# Saved model: best_fuel_consumption_model.pth
# Epoch [42/250] ---- Training Loss: 0.0167 ---- Validation Loss: 0.015521
# Saved model: best_fuel_consumption_model.pth
# Epoch [43/250] ---- Training Loss: 0.0167 ---- Validation Loss: 0.015452
# Saved model: best_fuel_consumption_model.pth
# Epoch [44/250] ---- Training Loss: 0.0166 ---- Validation Loss: 0.015395
# Saved model: best_fuel_consumption_model.pth
# Epoch [45/250] ---- Training Loss: 0.0166 ---- Validation Loss: 0.015397
# Saved model: best_fuel_consumption_model.pth
# Epoch [46/250] ---- Training Loss: 0.0165 ---- Validation Loss: 0.015392
# Saved model: best_fuel_consumption_model.pth
# Epoch [47/250] ---- Training Loss: 0.0165 ---- Validation Loss: 0.015237
# Saved model: best_fuel_consumption_model.pth
# Epoch [48/250] ---- Training Loss: 0.0164 ---- Validation Loss: 0.015195
# Saved model: best_fuel_consumption_model.pth
# Epoch [49/250] ---- Training Loss: 0.0164 ---- Validation Loss: 0.015169
# Saved model: best_fuel_consumption_model.pth
# Epoch [50/250] ---- Training Loss: 0.0164 ---- Validation Loss: 0.015115
# Saved model: best_fuel_consumption_model.pth
# Epoch [51/250] ---- Training Loss: 0.0163 ---- Validation Loss: 0.015074
# Saved model: best_fuel_consumption_model.pth
# Epoch [52/250] ---- Training Loss: 0.0163 ---- Validation Loss: 0.015068
# Saved model: best_fuel_consumption_model.pth
# Epoch [53/250] ---- Training Loss: 0.0163 ---- Validation Loss: 0.015038
# Saved model: best_fuel_consumption_model.pth
# Epoch [54/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.015022
# Saved model: best_fuel_consumption_model.pth
# Epoch [55/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.015008
# Saved model: best_fuel_consumption_model.pth
# Epoch [56/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.015016
# Saved model: best_fuel_consumption_model.pth
# Epoch [57/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.014941
# Saved model: best_fuel_consumption_model.pth
# Epoch [58/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.014940
# Saved model: best_fuel_consumption_model.pth
# Epoch [59/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.014919
# Saved model: best_fuel_consumption_model.pth
# Epoch [60/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.014905
# Saved model: best_fuel_consumption_model.pth
# Epoch [61/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.014865
# Saved model: best_fuel_consumption_model.pth
# Epoch [62/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.014856
# Saved model: best_fuel_consumption_model.pth
# Epoch [63/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.014854
# Saved model: best_fuel_consumption_model.pth
# Epoch [64/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.014811
# Saved model: best_fuel_consumption_model.pth
# Epoch [65/250] ---- Training Loss: 0.0160 ---- Validation Loss: 0.014789
# Saved model: best_fuel_consumption_model.pth
# Epoch [66/250] ---- Training Loss: 0.0160 ---- Validation Loss: 0.014752
# Saved model: best_fuel_consumption_model.pth
# Epoch [67/250] ---- Training Loss: 0.0160 ---- Validation Loss: 0.014771
# Saved model: best_fuel_consumption_model.pth
# Epoch [68/250] ---- Training Loss: 0.0160 ---- Validation Loss: 0.014716
# Saved model: best_fuel_consumption_model.pth
# Epoch [69/250] ---- Training Loss: 0.0160 ---- Validation Loss: 0.014681
# Saved model: best_fuel_consumption_model.pth
# Epoch [70/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014717
# Saved model: best_fuel_consumption_model.pth
# Epoch [71/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014655
# Saved model: best_fuel_consumption_model.pth
# Epoch [72/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014702
# Saved model: best_fuel_consumption_model.pth
# Epoch [73/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014625
# Saved model: best_fuel_consumption_model.pth
# Epoch [74/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014591
# Saved model: best_fuel_consumption_model.pth
# Epoch [75/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014594
# Saved model: best_fuel_consumption_model.pth
# Epoch [76/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.014550
# Saved model: best_fuel_consumption_model.pth
# Epoch [77/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.014520
# Saved model: best_fuel_consumption_model.pth
# Epoch [78/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.014511
# Saved model: best_fuel_consumption_model.pth
# Epoch [79/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.014528
# Saved model: best_fuel_consumption_model.pth
# Epoch [80/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.014480
# Saved model: best_fuel_consumption_model.pth
# Epoch [81/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014436
# Saved model: best_fuel_consumption_model.pth
# Epoch [82/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014416
# Saved model: best_fuel_consumption_model.pth
# Epoch [83/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014395
# Saved model: best_fuel_consumption_model.pth
# Epoch [84/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014449
# Saved model: best_fuel_consumption_model.pth
# Epoch [85/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014382
# Saved model: best_fuel_consumption_model.pth
# Epoch [86/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014381
# Saved model: best_fuel_consumption_model.pth
# Epoch [87/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014315
# Saved model: best_fuel_consumption_model.pth
# Epoch [88/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014363
# Saved model: best_fuel_consumption_model.pth
# Epoch [89/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014327
# Saved model: best_fuel_consumption_model.pth
# Epoch [90/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014276
# Saved model: best_fuel_consumption_model.pth
# Epoch [91/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014336
# Saved model: best_fuel_consumption_model.pth
# Epoch [92/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014286
# Saved model: best_fuel_consumption_model.pth
# Epoch [93/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014224
# Saved model: best_fuel_consumption_model.pth
# Epoch [94/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014204
# Saved model: best_fuel_consumption_model.pth
# Epoch [95/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014168
# Saved model: best_fuel_consumption_model.pth
# Epoch [96/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014171
# Saved model: best_fuel_consumption_model.pth
# Epoch [97/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014168
# Saved model: best_fuel_consumption_model.pth
# Epoch [98/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014265
# Saved model: best_fuel_consumption_model.pth
# Epoch [99/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014137
# Saved model: best_fuel_consumption_model.pth
# Epoch [100/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014106
# Saved model: best_fuel_consumption_model.pth
# Epoch [101/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014093
# Saved model: best_fuel_consumption_model.pth
# Epoch [102/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014083
# Saved model: best_fuel_consumption_model.pth
# Epoch [103/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014087
# Saved model: best_fuel_consumption_model.pth
# Epoch [104/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014065
# Saved model: best_fuel_consumption_model.pth
# Epoch [105/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014037
# Saved model: best_fuel_consumption_model.pth
# Epoch [106/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014028
# Saved model: best_fuel_consumption_model.pth
# Epoch [107/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.014051
# Saved model: best_fuel_consumption_model.pth
# Epoch [108/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.014019
# Saved model: best_fuel_consumption_model.pth
# Epoch [109/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.014015
# Saved model: best_fuel_consumption_model.pth
# Epoch [110/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.014015
# Saved model: best_fuel_consumption_model.pth
# Epoch [111/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013986
# Saved model: best_fuel_consumption_model.pth
# Epoch [112/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013979
# Saved model: best_fuel_consumption_model.pth
# Epoch [113/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013951
# Saved model: best_fuel_consumption_model.pth
# Epoch [114/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013959
# Saved model: best_fuel_consumption_model.pth
# Epoch [115/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013938
# Saved model: best_fuel_consumption_model.pth
# Epoch [116/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013958
# Saved model: best_fuel_consumption_model.pth
# Epoch [117/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.013955
# Saved model: best_fuel_consumption_model.pth
# Epoch [118/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013912
# Saved model: best_fuel_consumption_model.pth
# Epoch [119/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013955
# Saved model: best_fuel_consumption_model.pth
# Epoch [120/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013903
# Saved model: best_fuel_consumption_model.pth
# Epoch [121/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013906
# Saved model: best_fuel_consumption_model.pth
# Epoch [122/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013878
# Saved model: best_fuel_consumption_model.pth
# Epoch [123/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013861
# Saved model: best_fuel_consumption_model.pth
# Epoch [124/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013857
# Saved model: best_fuel_consumption_model.pth
# Epoch [125/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013854
# Saved model: best_fuel_consumption_model.pth
# Epoch [126/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013842
# Saved model: best_fuel_consumption_model.pth
# Epoch [127/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013866
# Saved model: best_fuel_consumption_model.pth
# Epoch [128/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013846
# Saved model: best_fuel_consumption_model.pth
# Epoch [129/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013817
# Saved model: best_fuel_consumption_model.pth
# Epoch [130/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013795
# Saved model: best_fuel_consumption_model.pth
# Epoch [131/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.013796
# Saved model: best_fuel_consumption_model.pth
# Epoch [132/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013800
# Saved model: best_fuel_consumption_model.pth
# Epoch [133/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013776
# Saved model: best_fuel_consumption_model.pth
# Epoch [134/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013773
# Saved model: best_fuel_consumption_model.pth
# Epoch [135/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013771
# Saved model: best_fuel_consumption_model.pth
# Epoch [136/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013752
# Saved model: best_fuel_consumption_model.pth
# Epoch [137/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013745
# Saved model: best_fuel_consumption_model.pth
# Epoch [138/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013729
# Saved model: best_fuel_consumption_model.pth
# Epoch [139/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013724
# Saved model: best_fuel_consumption_model.pth
# Epoch [140/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013719
# Saved model: best_fuel_consumption_model.pth
# Epoch [141/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013714
# Saved model: best_fuel_consumption_model.pth
# Epoch [142/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013705
# Saved model: best_fuel_consumption_model.pth
# Epoch [143/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013680
# Saved model: best_fuel_consumption_model.pth
# Epoch [144/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.013682
# Saved model: best_fuel_consumption_model.pth
# Epoch [145/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013684
# Saved model: best_fuel_consumption_model.pth
# Epoch [146/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013656
# Saved model: best_fuel_consumption_model.pth
# Epoch [147/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013690
# Saved model: best_fuel_consumption_model.pth
# Epoch [148/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013643
# Saved model: best_fuel_consumption_model.pth
# Epoch [149/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013719
# Saved model: best_fuel_consumption_model.pth
# Epoch [150/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013650
# Saved model: best_fuel_consumption_model.pth
# Epoch [151/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013618
# Saved model: best_fuel_consumption_model.pth
# Epoch [152/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013604
# Saved model: best_fuel_consumption_model.pth
# Epoch [153/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013615
# Saved model: best_fuel_consumption_model.pth
# Epoch [154/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013620
# Saved model: best_fuel_consumption_model.pth
# Epoch [155/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013599
# Saved model: best_fuel_consumption_model.pth
# Epoch [156/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013620
# Saved model: best_fuel_consumption_model.pth
# Epoch [157/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013603
# Saved model: best_fuel_consumption_model.pth
# Epoch [158/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013617
# Saved model: best_fuel_consumption_model.pth
# Epoch [159/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.013588
# Saved model: best_fuel_consumption_model.pth
# Epoch [160/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013582
# Saved model: best_fuel_consumption_model.pth
# Epoch [161/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013580
# Saved model: best_fuel_consumption_model.pth
# Epoch [162/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013566
# Saved model: best_fuel_consumption_model.pth
# Epoch [163/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013569
# Saved model: best_fuel_consumption_model.pth
# Epoch [164/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013571
# Saved model: best_fuel_consumption_model.pth
# Epoch [165/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013564
# Saved model: best_fuel_consumption_model.pth
# Epoch [166/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013553
# Saved model: best_fuel_consumption_model.pth
# Epoch [167/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013559
# Saved model: best_fuel_consumption_model.pth
# Epoch [168/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013563
# Saved model: best_fuel_consumption_model.pth
# Epoch [169/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013548
# Saved model: best_fuel_consumption_model.pth
# Epoch [170/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013548
# Saved model: best_fuel_consumption_model.pth
# Epoch [171/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013557
# Saved model: best_fuel_consumption_model.pth
# Epoch [172/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013537
# Saved model: best_fuel_consumption_model.pth
# Epoch [173/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013525
# Saved model: best_fuel_consumption_model.pth
# Epoch [174/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013532
# Saved model: best_fuel_consumption_model.pth
# Epoch [175/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013527
# Saved model: best_fuel_consumption_model.pth
# Epoch [176/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013519
# Saved model: best_fuel_consumption_model.pth
# Epoch [177/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013524
# Saved model: best_fuel_consumption_model.pth
# Epoch [178/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013514
# Saved model: best_fuel_consumption_model.pth
# Epoch [179/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013507
# Saved model: best_fuel_consumption_model.pth
# Epoch [180/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013496
# Saved model: best_fuel_consumption_model.pth
# Epoch [181/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013499
# Saved model: best_fuel_consumption_model.pth
# Epoch [182/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013485
# Saved model: best_fuel_consumption_model.pth
# Epoch [183/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013499
# Saved model: best_fuel_consumption_model.pth
# Epoch [184/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013486
# Saved model: best_fuel_consumption_model.pth
# Epoch [185/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013482
# Saved model: best_fuel_consumption_model.pth
# Epoch [186/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013474
# Saved model: best_fuel_consumption_model.pth
# Epoch [187/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013476
# Saved model: best_fuel_consumption_model.pth
# Epoch [188/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013492
# Saved model: best_fuel_consumption_model.pth
# Epoch [189/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013475
# Saved model: best_fuel_consumption_model.pth
# Epoch [190/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013454
# Saved model: best_fuel_consumption_model.pth
# Epoch [191/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013463
# Saved model: best_fuel_consumption_model.pth
# Epoch [192/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013478
# Saved model: best_fuel_consumption_model.pth
# Epoch [193/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013454
# Saved model: best_fuel_consumption_model.pth
# Epoch [194/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013476
# Saved model: best_fuel_consumption_model.pth
# Epoch [195/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013449
# Saved model: best_fuel_consumption_model.pth
# Epoch [196/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013440
# Saved model: best_fuel_consumption_model.pth
# Epoch [197/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013435
# Saved model: best_fuel_consumption_model.pth
# Epoch [198/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.013449
# Saved model: best_fuel_consumption_model.pth
# Epoch [199/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013431
# Saved model: best_fuel_consumption_model.pth
# Epoch [200/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013434
# Saved model: best_fuel_consumption_model.pth
# Epoch [201/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013420
# Saved model: best_fuel_consumption_model.pth
# Epoch [202/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013418
# Saved model: best_fuel_consumption_model.pth
# Epoch [203/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013435
# Saved model: best_fuel_consumption_model.pth
# Epoch [204/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013415
# Saved model: best_fuel_consumption_model.pth
# Epoch [205/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013415
# Saved model: best_fuel_consumption_model.pth
# Epoch [206/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013418
# Saved model: best_fuel_consumption_model.pth
# Epoch [207/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013415
# Saved model: best_fuel_consumption_model.pth
# Epoch [208/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013412
# Saved model: best_fuel_consumption_model.pth
# Epoch [209/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013403
# Saved model: best_fuel_consumption_model.pth
# Epoch [210/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013406
# Saved model: best_fuel_consumption_model.pth
# Epoch [211/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013403
# Saved model: best_fuel_consumption_model.pth
# Epoch [212/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013404
# Saved model: best_fuel_consumption_model.pth
# Epoch [213/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013402
# Saved model: best_fuel_consumption_model.pth
# Epoch [214/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013403
# Saved model: best_fuel_consumption_model.pth
# Epoch [215/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013404
# Saved model: best_fuel_consumption_model.pth
# Epoch [216/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013393
# Saved model: best_fuel_consumption_model.pth
# Epoch [217/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013389
# Saved model: best_fuel_consumption_model.pth
# Epoch [218/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013395
# Saved model: best_fuel_consumption_model.pth
# Epoch [219/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013384
# Saved model: best_fuel_consumption_model.pth
# Epoch [220/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013388
# Saved model: best_fuel_consumption_model.pth
# Epoch [221/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013385
# Saved model: best_fuel_consumption_model.pth
# Epoch [222/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013383
# Saved model: best_fuel_consumption_model.pth
# Epoch [223/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013377
# Saved model: best_fuel_consumption_model.pth
# Epoch [224/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013376
# Saved model: best_fuel_consumption_model.pth
# Epoch [225/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013376
# Saved model: best_fuel_consumption_model.pth
# Epoch [226/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013405
# Saved model: best_fuel_consumption_model.pth
# Epoch [227/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013391
# Saved model: best_fuel_consumption_model.pth
# Epoch [228/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013366
# Saved model: best_fuel_consumption_model.pth
# Epoch [229/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013371
# Saved model: best_fuel_consumption_model.pth
# Epoch [230/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013371
# Saved model: best_fuel_consumption_model.pth
# Epoch [231/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013364
# Saved model: best_fuel_consumption_model.pth
# Epoch [232/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013362
# Saved model: best_fuel_consumption_model.pth
# Epoch [233/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013361
# Saved model: best_fuel_consumption_model.pth
# Epoch [234/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013360
# Saved model: best_fuel_consumption_model.pth
# Epoch [235/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013358
# Saved model: best_fuel_consumption_model.pth
# Epoch [236/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013364
# Saved model: best_fuel_consumption_model.pth
# Epoch [237/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013358
# Saved model: best_fuel_consumption_model.pth
# Epoch [238/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013353
# Saved model: best_fuel_consumption_model.pth
# Epoch [239/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013355
# Saved model: best_fuel_consumption_model.pth
# Epoch [240/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013353
# Saved model: best_fuel_consumption_model.pth
# Epoch [241/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013345
# Saved model: best_fuel_consumption_model.pth
# Epoch [242/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013347
# Saved model: best_fuel_consumption_model.pth
# Epoch [243/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013345
# Saved model: best_fuel_consumption_model.pth
# Epoch [244/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013338
# Saved model: best_fuel_consumption_model.pth
# Epoch [245/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013347
# Saved model: best_fuel_consumption_model.pth
# Epoch [246/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013336
# Saved model: best_fuel_consumption_model.pth
# Epoch [247/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013336
# Saved model: best_fuel_consumption_model.pth
# Epoch [248/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013338
# Saved model: best_fuel_consumption_model.pth
# Epoch [249/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013339
# Saved model: best_fuel_consumption_model.pth
# Epoch [250/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013332
# Saved model: best_fuel_consumption_model.pth

# %% [markdown]
# #test

# %% [markdown]
# #Test with all saved model

# %%
# Out:
# Testing model: best_fuel_consumption_model_batch32_l200_without_acc
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch32_l200_without_acc.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch32_l200_without_acc.csv
# Testing model: best_fuel_consumption_model_batch45_l200_without_acc
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200_without_acc.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200_without_acc.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 200  # Updated sequence length
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['Time'] - df['Time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip fuel consumption'] - df['Trip fuel consumption'].iloc[0]
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    features = df[['Engine speed', 'Speed', 'slope', 'Acceleration']]
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [6, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values], sequence_length=remainder)
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Save plot using model name
    directory, filename = os.path.split(input_file)
    plot_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_predicted_vs_real_{model_name}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name
    results_df = pd.DataFrame({
        'Speed': features["Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_predicted_vs_real_{model_name}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/NEDC_1000_slope_added.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Current_gear_shift_position_(Current_gear)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-d525fb204d14> in <cell line: 131>()
#     135
#     136     model = load_trained_model(model_path, input_size)
# --> 137     plot_predicted_vs_real(input_file_path, model, model_name)
#
# <ipython-input-50-d525fb204d14> in plot_predicted_vs_real(input_file, model, model_name)
#      70 # Predict and plot the results
#      71 def plot_predicted_vs_real(input_file, model, model_name):
# ---> 72     features, actual_values = process_file(input_file)
#      73     num_segments = len(features) // SEQUENCE_LENGTH
#      74     predictions = []
#
# <ipython-input-50-d525fb204d14> in process_file(file_path)
#      46     df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
#      47
# ---> 48     df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})
#      49
#      50     # Selecting features and target
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Current_gear_shift_position_(Current_gear)'

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 200  # Updated sequence length
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'  # Base directory to save plots and CSVs
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Ensure the base save directory exists
os.makedirs(PLOT_SAVE_DIR, exist_ok=True)

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['time'] - df['time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip_fuel_consumption'] - df['Trip_fuel_consumption'].iloc[0]
    df['Acceleration'] = df['Vehicle_Speed'].diff().fillna(0)
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Vehicle_Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [6, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values], sequence_length=remainder)
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Create model-specific directory
    model_save_dir = os.path.join(PLOT_SAVE_DIR, model_name)
    os.makedirs(model_save_dir, exist_ok=True)

    # Save plot using model name in the designated directory
    plot_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}_predicted_vs_real_{model_name}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name in the designated directory
    results_df = pd.DataFrame({
        'Speed': features["Vehicle_Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}_predicted_vs_real_{model_name}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/output_file_56.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model/output_file_56_predicted_vs_real_best_fuel_consumption_model.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model/output_file_56_predicted_vs_real_best_fuel_consumption_model.csv

# %%
# !rm -r '/content/predicted_vs_actual_plots'

# %%
# !zip -r /content/predicted_vs_actual_plots.zip /content/predicted_vs_actual_plots
# Out:
#   adding: content/predicted_vs_actual_plots/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 52%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_11_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 64%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_11_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_6_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_21_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_27_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_44_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_6_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_35_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_48_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_27_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_53_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_21_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_35_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_53_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_44_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_17_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_17_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_48_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_11_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 64%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_21_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_44_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_27_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_27_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_48_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_11_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_17_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_53_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_53_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_6_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_17_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_6_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_48_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_35_predicted_vs_real_best_fuel_consumption_model_batch45_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_35_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_44_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch45_l200/output_file_21_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_21_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_35_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_27_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_48_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_53_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_17_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_27_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_44_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_6_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_6_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 58%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_44_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_17_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_11_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_11_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 64%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_48_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_53_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_21_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_35_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 52%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 52%)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp "/content/gdrive/My Drive/DataAugumentation.zip" .
#ADDED NEW SOURCE
# !cp "/content/gdrive/MyDrive/data_aug(3_slices_with_repeated)_cluster_5_ehsan_0.5.zip" .
# !unzip -qq DataAugumentation.zip
# !unzip -qq data_aug_3_slices_with_repeated_cluster_5.zip
# !rm DataAugumentation.zip
# !rm data_aug_3_slices_with_repeated_cluster_5.zip
data_path = 'DataAugumentation'
# Out:
# unzip:  cannot find or open DataAugumentation.zip, DataAugumentation.zip.zip or DataAugumentation.zip.ZIP.
# unzip:  cannot find or open data_aug_3_slices_with_repeated_cluster_5.zip, data_aug_3_slices_with_repeated_cluster_5.zip.zip or data_aug_3_slices_with_repeated_cluster_5.zip.ZIP.
# rm: cannot remove 'DataAugumentation.zip': No such file or directory
# rm: cannot remove 'data_aug_3_slices_with_repeated_cluster_5.zip': No such file or directory

# %%
# !unzip -qq '/content/data_aug(3_slices_with_repeated)_cluster_5_ehsan_0.5.zip'

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
import joblib

SEQUENCE_LENGTH = 200  # Updated sequence length
BATCH_SIZE = 64
EPOCHS = 250
LEARNING_RATE = 1e-5
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)

# Data processing function
def process_file(file_path):
    df = pd.read_csv(file_path)
    # print(df)
    df['Time'] = df['Time'] - df['Time'].iloc[0]

    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']


    return features.values, target.values

# Function to slice data into chunks and append to lists
def slice_and_append(features, target, sequence_length, X_list, y_list):
    num_chunks = len(features) // sequence_length  # Should be 12 for your case

    for i in range(num_chunks):
        start_idx = i * sequence_length
        end_idx = start_idx + sequence_length

        # Slicing the features and target arrays
        sliced_features = features[start_idx:end_idx]
        sliced_target = target[start_idx:end_idx]

        # Append the sliced features and target to the respective lists
        X_list.append(sliced_features)
        y_list.append(sliced_target)

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_original = []
y_original = []
X_augmented = []
y_augmented = []

base_folder_path = '/content/'

# Process the data and slice into smaller DataFrames
for i in range(6):
    if i == 5:
        folder_path = os.path.join(base_folder_path, f'data_aug(3_slices_with_repeated)_cluster_{i}')
        for filename in os.listdir(folder_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(folder_path, filename)
                features, target = process_file(file_path)

                slices = filename.split('_')
                is_original_trip = slices[2] == slices[6] and slices[6] == slices[10]

                if is_original_trip:
                    slice_and_append(features, target, SEQUENCE_LENGTH, X_original, y_original)
                else:
                    slice_and_append(features, target, SEQUENCE_LENGTH, X_augmented, y_augmented)
# Out:
# cuda

# %%
# Function to pad or truncate sequences
def pad_or_truncate(sequence, length):
    if len(sequence) > length:
        return sequence[:length]
    elif len(sequence) < length:
        return np.pad(sequence, ((0, length - len(sequence)), (0, 0)), mode='constant')
    else:
        return sequence

# %%
# Apply padding/truncating to ensure consistent sequence length
X_original = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_original]
y_original = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_original]
X_augmented = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_augmented]
y_augmented = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_augmented]

# %%
# Convert data to PyTorch tensors
try:
    X_original = torch.tensor(np.array(X_original), dtype=torch.float32).to(DEVICE)
    y_original = torch.tensor(np.array(y_original), dtype=torch.float32).to(DEVICE)
    X_augmented = torch.tensor(np.array(X_augmented), dtype=torch.float32).to(DEVICE)
    y_augmented = torch.tensor(np.array(y_augmented), dtype=torch.float32).to(DEVICE)
except Exception as e:
    print(f"Error during tensor conversion: {e}")
    print(f"Shapes: X_original - {np.array(X_original).shape}, y_original - {np.array(y_original).shape}")
    print(f"Shapes: X_augmented - {np.array(X_augmented).shape}, y_augmented - {np.array(y_augmented).shape}")
    raise

# %%
# Split into training and test sets
# num_test = int(0.2 * len(X_original))
# X_test = X_original[:num_test]
# y_test = y_original[:num_test]
# X_train = torch.cat([X_original[num_test:], X_augmented])
# y_train = torch.cat([y_original[num_test:], y_augmented])


X_train = torch.cat([X_original, X_augmented])
y_train = torch.cat([y_original, y_augmented])
# X_train = X_original[num_test:]
# y_train = y_original[num_test:]

# %%
# Convert the min and max values to tensors
min_val_x = torch.tensor([0, 0, -10, -10], dtype=torch.float32).to(DEVICE)
max_val_x = torch.tensor([6, 150, 10, 10], dtype=torch.float32).to(DEVICE)

min_val_y = torch.tensor([0], dtype=torch.float32).to(DEVICE)
max_val_y = torch.tensor([10000], dtype=torch.float32).to(DEVICE)

# Custom normalization function for X
def custom_normalize_X(data, min_vals, max_vals):
    for i in range(data.shape[-1]):
        data[:, :, i] = (data[:, :, i] - min_vals[i]) / (max_vals[i] - min_vals[i])
    return data

# Custom normalization function for y
def custom_normalize_y(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# Normalize X_train and X_test
X_train_normalized = custom_normalize_X(X_train, min_val_x, max_val_x)
# X_test_normalized = custom_normalize_X(X_test, min_val_x, max_val_x)

# Normalize y_train and y_test
y_train_normalized = custom_normalize_y(y_train, min_val_y, max_val_y)
# y_test_normalized = custom_normalize_y(y_test, min_val_y, max_val_y)

# %%
# Define the PyTorch model
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# %%
# Instantiate the model, define the loss function and the optimizer
model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
criterion = nn.L1Loss()
weight_decay = 1e-4  # L2 regularization factor
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=weight_decay)

# %%
# Assume 80% of the data is used for training and 20% for validation
train_size = int(0.8 * len(X_train_normalized))
val_size = len(X_train_normalized) - train_size

# Split the data while preserving the order
X_train_split = X_train_normalized[:train_size]
y_train_split = y_train_normalized[:train_size]

X_val_split = X_train_normalized[train_size:]
y_val_split = y_train_normalized[train_size:]



# BATCH_SIZE = 96
# # Create DataLoader for training and validation sets
# train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
# val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR  # Importing StepLR for learning rate decay

# Assuming `FuelConsumptionModel`, `X_train_normalized`, `train_loader`, `val_loader`, `DEVICE`, and `EPOCHS` are defined

# Choose a single loss function to use for all experiments
criterion = nn.L1Loss()  # You can change this to your preferred loss function

# Define weight decay values and initial learning rates for decay schedules
weight_decay_values = 1e-5
initial_learning_rates = [1e-4]  # Two starting learning rates

# Initialize variables to track the best parameters
best_weight_decay = None
best_initial_lr = None
best_model_weights = None
best_val_loss = float('inf')

ini_batches = [64]
# Loop over all combinations of initial learning rates and weight decay values

BATCH_SIZE = 64
# Create DataLoader for training and validation sets
train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

for init_lr in initial_learning_rates:
    # Initialize model, criterion, and optimizer for each combination
    model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=weight_decay_values)
    scheduler = StepLR(optimizer, step_size=50, gamma=0.5)  # Decay LR by 0.5 every 50 epochs

    # Early stopping parameters
    patience = 10  # Number of epochs to wait before stopping if no improvement
    best_loss = float('inf')  # Initialize best loss to infinity
    epochs_without_improvement = 0  # Counter for epochs without improvement

    # Training loop with early stopping
    model.train()
    for epoch in range(EPOCHS):
        running_loss = 0.0
        model.train()  # Ensure model is in training mode

        # Training phase
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Calculate average loss for the epoch
        avg_training_loss = running_loss / len(train_loader)

        # Validation phase
        model.eval()  # Switch to evaluation mode
        val_running_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:  # Assume you have a validation DataLoader `val_loader`
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
                outputs = model(inputs)
                val_loss = criterion(outputs, targets)
                val_running_loss += val_loss.item()

        avg_val_loss = val_running_loss / len(val_loader)

        current_lr = optimizer.param_groups[0]['lr']
        print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.6f}")

        # print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.4f}    Init LR: {init_lr:.0e}  WD: {wd:.0e}")

        # Adjust the learning rate
        scheduler.step()

        # Early stopping check
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
            if epochs_without_improvement >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

        # Save the model for the current combination
        model_filename = f'best_fuel_consumption_model.pth'
        torch.save(model.state_dict(), model_filename)


print(f"Saved model: {model_filename}")
# Out:
# Epoch [1/250] ---- Training Loss: 0.0345 ---- Validation Loss: 0.027685
# Epoch [2/250] ---- Training Loss: 0.0292 ---- Validation Loss: 0.025900
# Epoch [3/250] ---- Training Loss: 0.0269 ---- Validation Loss: 0.025113
# Epoch [4/250] ---- Training Loss: 0.0258 ---- Validation Loss: 0.024427
# Epoch [5/250] ---- Training Loss: 0.0250 ---- Validation Loss: 0.023909
# Epoch [6/250] ---- Training Loss: 0.0243 ---- Validation Loss: 0.023233
# Epoch [7/250] ---- Training Loss: 0.0237 ---- Validation Loss: 0.022622
# Epoch [8/250] ---- Training Loss: 0.0233 ---- Validation Loss: 0.022456
# Epoch [9/250] ---- Training Loss: 0.0229 ---- Validation Loss: 0.021907
# Epoch [10/250] ---- Training Loss: 0.0226 ---- Validation Loss: 0.021557
# Epoch [11/250] ---- Training Loss: 0.0221 ---- Validation Loss: 0.021017
# Epoch [12/250] ---- Training Loss: 0.0216 ---- Validation Loss: 0.020434
# Epoch [13/250] ---- Training Loss: 0.0210 ---- Validation Loss: 0.019612
# Epoch [14/250] ---- Training Loss: 0.0203 ---- Validation Loss: 0.019012
# Epoch [15/250] ---- Training Loss: 0.0197 ---- Validation Loss: 0.018463
# Epoch [16/250] ---- Training Loss: 0.0192 ---- Validation Loss: 0.018051
# Epoch [17/250] ---- Training Loss: 0.0188 ---- Validation Loss: 0.017610
# Epoch [18/250] ---- Training Loss: 0.0183 ---- Validation Loss: 0.017150
# Epoch [19/250] ---- Training Loss: 0.0179 ---- Validation Loss: 0.016784
# Epoch [20/250] ---- Training Loss: 0.0176 ---- Validation Loss: 0.016464
# Epoch [21/250] ---- Training Loss: 0.0173 ---- Validation Loss: 0.016161
# Epoch [22/250] ---- Training Loss: 0.0170 ---- Validation Loss: 0.015894
# Epoch [23/250] ---- Training Loss: 0.0168 ---- Validation Loss: 0.015672
# Epoch [24/250] ---- Training Loss: 0.0166 ---- Validation Loss: 0.015502
# Epoch [25/250] ---- Training Loss: 0.0164 ---- Validation Loss: 0.015429
# Epoch [26/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.015191
# Epoch [27/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.015049
# Epoch [28/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.014951
# Epoch [29/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.014884
# Epoch [30/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.014865
# Epoch [31/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.014675
# Epoch [32/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014636
# Epoch [33/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.014524
# Epoch [34/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.014587
# Epoch [35/250] ---- Training Loss: 0.0153 ---- Validation Loss: 0.014405
# Epoch [36/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.014358
# Epoch [37/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.014254
# Epoch [38/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.014213
# Epoch [39/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.014161
# Epoch [40/250] ---- Training Loss: 0.0150 ---- Validation Loss: 0.014109
# Epoch [41/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.014010
# Epoch [42/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013956
# Epoch [43/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.013944
# Epoch [44/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013876
# Epoch [45/250] ---- Training Loss: 0.0147 ---- Validation Loss: 0.013792
# Epoch [46/250] ---- Training Loss: 0.0146 ---- Validation Loss: 0.013723
# Epoch [47/250] ---- Training Loss: 0.0146 ---- Validation Loss: 0.013684
# Epoch [48/250] ---- Training Loss: 0.0145 ---- Validation Loss: 0.013593
# Epoch [49/250] ---- Training Loss: 0.0144 ---- Validation Loss: 0.013512
# Epoch [50/250] ---- Training Loss: 0.0144 ---- Validation Loss: 0.013454
# Epoch [52/250] ---- Training Loss: 0.0143 ---- Validation Loss: 0.013375
# Epoch [53/250] ---- Training Loss: 0.0143 ---- Validation Loss: 0.013355
# Epoch [54/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.013299
# Epoch [55/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.013267
# Epoch [56/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.013251
# Epoch [57/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.013222
# Epoch [58/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.013189
# Epoch [59/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.013162
# Epoch [60/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.013145
# Epoch [61/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.013139
# Epoch [62/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013101
# Epoch [63/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013092
# Epoch [64/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013060
# Epoch [65/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013038
# Epoch [66/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.013023
# Epoch [67/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.012990
# Epoch [68/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.012971
# Epoch [69/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.012958
# Epoch [70/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.012923
# Epoch [71/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.012889
# Epoch [72/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.012883
# Epoch [73/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.012878
# Epoch [74/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.012823
# Epoch [75/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.012807
# Epoch [76/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012781
# Epoch [77/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012845
# Epoch [78/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012725
# Epoch [79/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012709
# Epoch [80/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.012724
# Epoch [81/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012669
# Epoch [82/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012651
# Epoch [83/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012649
# Epoch [84/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012610
# Epoch [85/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.012593
# Epoch [86/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012584
# Epoch [87/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012591
# Epoch [88/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012574
# Epoch [89/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012543
# Epoch [90/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012524
# Epoch [91/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012515
# Epoch [92/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.012483
# Epoch [93/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012489
# Epoch [94/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012458
# Epoch [95/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012484
# Epoch [96/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012445
# Epoch [97/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012439
# Epoch [98/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.012403
# Epoch [99/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012386
# Epoch [100/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012374
# Epoch [101/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012351
# Epoch [102/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012344
# Epoch [103/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012330
# Epoch [104/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012319
# Epoch [105/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012323
# Epoch [106/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012305
# Epoch [107/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012299
# Epoch [108/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012285
# Epoch [109/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.012287
# Epoch [110/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012289
# Epoch [111/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012266
# Epoch [112/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012267
# Epoch [113/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012261
# Epoch [114/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012260
# Epoch [115/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012246
# Epoch [116/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012227
# Epoch [117/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012231
# Epoch [118/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012220
# Epoch [119/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012209
# Epoch [120/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012223
# Epoch [121/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012211
# Epoch [122/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012191
# Epoch [123/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012186
# Epoch [124/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.012196
# Epoch [125/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012180
# Epoch [126/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012164
# Epoch [127/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012154
# Epoch [128/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012170
# Epoch [129/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012135
# Epoch [130/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012153
# Epoch [131/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012124
# Epoch [132/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012128
# Epoch [133/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012120
# Epoch [134/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012105
# Epoch [135/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012100
# Epoch [136/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012118
# Epoch [137/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012133
# Epoch [138/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012092
# Epoch [139/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.012095
# Epoch [140/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012076
# Epoch [141/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012063
# Epoch [142/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012056
# Epoch [143/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012055
# Epoch [144/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012046
# Epoch [145/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012028
# Epoch [146/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012034
# Epoch [147/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012035
# Epoch [148/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012010
# Epoch [149/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012006
# Epoch [150/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012005
# Epoch [151/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.012004
# Epoch [152/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011991
# Epoch [153/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011998
# Epoch [154/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011991
# Epoch [155/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011991
# Epoch [156/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011982
# Epoch [157/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011979
# Epoch [158/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011980
# Epoch [159/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.011972
# Epoch [160/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011981
# Epoch [161/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011962
# Epoch [162/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011970
# Epoch [163/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011966
# Epoch [164/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011948
# Epoch [165/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011952
# Epoch [166/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011947
# Epoch [167/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011943
# Epoch [168/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011938
# Epoch [169/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011934
# Epoch [170/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011939
# Epoch [171/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011934
# Epoch [172/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011926
# Epoch [173/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011939
# Epoch [174/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011941
# Epoch [175/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011925
# Epoch [176/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011923
# Epoch [177/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011934
# Epoch [178/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011919
# Epoch [179/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011905
# Epoch [180/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011899
# Epoch [181/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011901
# Epoch [182/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011900
# Epoch [183/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011888
# Epoch [184/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011887
# Epoch [185/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011884
# Epoch [186/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011887
# Epoch [187/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011893
# Epoch [188/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011873
# Epoch [189/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011872
# Epoch [190/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011869
# Epoch [191/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011866
# Epoch [192/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.011864
# Epoch [193/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011873
# Epoch [194/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011859
# Epoch [195/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011874
# Epoch [196/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011846
# Epoch [197/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011850
# Epoch [198/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011853
# Epoch [199/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011848
# Epoch [200/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011834
# Epoch [201/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011841
# Epoch [202/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011837
# Epoch [203/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011835
# Epoch [204/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011838
# Epoch [205/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011838
# Epoch [206/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011827
# Epoch [207/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011826
# Epoch [208/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011831
# Epoch [209/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011833
# Epoch [210/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011822
# Epoch [211/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011824
# Epoch [212/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011818
# Epoch [213/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011815
# Epoch [214/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011818
# Epoch [215/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011818
# Epoch [216/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011814
# Epoch [217/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011813
# Epoch [218/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011809
# Epoch [220/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011811
# Epoch [221/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011809
# Epoch [222/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011806
# Epoch [223/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011797
# Epoch [224/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011797
# Epoch [225/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011801
# Epoch [226/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011797
# Epoch [227/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011796
# Epoch [228/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011794
# Epoch [229/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011791
# Epoch [230/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011789
# Epoch [231/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011797
# Epoch [232/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011788
# Epoch [233/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011786
# Epoch [234/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011785
# Epoch [235/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011791
# Epoch [236/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011788
# Epoch [237/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011789
# Epoch [238/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011776
# Epoch [239/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011780
# Epoch [240/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011773
# Epoch [241/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011774
# Epoch [242/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011787
# Epoch [243/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011764
# Epoch [244/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011766
# Epoch [245/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011763
# Epoch [246/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011768
# Epoch [247/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011761
# Epoch [248/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011769
# Epoch [249/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.011764
# Epoch [250/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.011757
# Saved model: best_fuel_consumption_model.pth

# %% [markdown]
# #test

# %% [markdown]
# #Test with all saved model

# %%
# Out:
# Testing model: best_fuel_consumption_model_batch32_l200_without_acc
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch32_l200_without_acc.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch32_l200_without_acc.csv
# Testing model: best_fuel_consumption_model_batch45_l200_without_acc
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200_without_acc.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch45_l200_without_acc.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 200  # Updated sequence length
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['Time'] - df['Time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip fuel consumption'] - df['Trip fuel consumption'].iloc[0]
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    features = df[['Engine speed', 'Speed', 'slope', 'Acceleration']]
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    df['Adjusted_gear_position'] = df['gear'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [6, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values], sequence_length=remainder)
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Save plot using model name
    directory, filename = os.path.split(input_file)
    plot_filename = os.path.join(f'{os.path.splitext(filename)[0]}_{model_name}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name
    results_df = pd.DataFrame({
        'Speed': features["Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/NEDC_1000_slope_added_with_gear.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model
# <ipython-input-16-b91582e01445>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: NEDC_1000_slope_added_with_gear_best_fuel_consumption_model.png
# CSV saved as: /content/NEDC_1000_slope_added_with_gear_predicted_vs_real_best_fuel_consumption_model.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 200  # Updated sequence length
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'  # Base directory to save plots and CSVs
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Ensure the base save directory exists
os.makedirs(PLOT_SAVE_DIR, exist_ok=True)

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['time'] - df['time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip_fuel_consumption'] - df['Trip_fuel_consumption'].iloc[0]
    df['Acceleration'] = df['Vehicle_Speed'].diff().fillna(0)
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    df['Adjusted_gear_position'] = df['Current_gear_shift_position_(Current_gear)'].replace({13: 0, 14: 1})

    # Selecting features and target
    features = df[['Adjusted_gear_position', 'Vehicle_Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [6, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values], sequence_length=remainder)
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Create model-specific directory
    model_save_dir = os.path.join(PLOT_SAVE_DIR, model_name)
    os.makedirs(model_save_dir, exist_ok=True)

    # Save plot using model name in the designated directory
    plot_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name in the designated directory
    results_df = pd.DataFrame({
        'Speed': features["Vehicle_Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/output_file_ehsan_1_4.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model
# <ipython-input-25-a66551cec6f7>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4.csv

# %%
# !rm -r '/content/predicted_vs_actual_plots'

# %%
# !zip -r /content/predicted_vs_actual_plots.zip /content/predicted_vs_actual_plots
# Out:
#   adding: content/predicted_vs_actual_plots/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_1_slope_added.csv (deflated 59%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/2_2_slope_added.csv (deflated 62%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4.csv (deflated 60%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/2_1_slope_added.png (deflated 11%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/3_5_slope_added.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_2_slope_added.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/6_1_slope_added.csv (deflated 54%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_4.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_2.csv (deflated 61%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/3_5_slope_added.csv (deflated 65%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_3.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_1_slope_added.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_3.csv (deflated 62%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/2_2_slope_added.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/2_1_slope_added.csv (deflated 57%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/6_1_slope_added.png (deflated 10%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/1_2_slope_added.csv (deflated 64%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model/output_file_ehsan_1_2.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_with_gear_predicted_vs_real_best_fuel_consumption_model.csv (deflated 52%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model.pth (deflated 7%)
#   adding: content/predicted_vs_actual_plots/NEDC_1000_slope_added_with_gear_best_fuel_consumption_model.png (deflated 9%)

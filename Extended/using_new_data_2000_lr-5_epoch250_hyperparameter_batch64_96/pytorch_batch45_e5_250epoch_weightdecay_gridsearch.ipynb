# %%
from google.colab import drive
drive.mount('/content/gdrive')


# !cp "/content/gdrive/My Drive/DataAugumentation.zip" .
#ADDED NEW SOURCE
# !cp "/content/gdrive/My Drive/data_aug(3_slices_with_repeated)_acceleration_full_data_20000.zip" .
# !unzip -qq DataAugumentation.zip
# !unzip -qq data_aug_3_slices_with_repeated_cluster_5.zip
# !rm DataAugumentation.zip
# !rm data_aug_3_slices_with_repeated_cluster_5.zip
data_path = 'DataAugumentation'
# Out:
# Mounted at /content/gdrive
# unzip:  cannot find or open DataAugumentation.zip, DataAugumentation.zip.zip or DataAugumentation.zip.ZIP.
# unzip:  cannot find or open data_aug_3_slices_with_repeated_cluster_5.zip, data_aug_3_slices_with_repeated_cluster_5.zip.zip or data_aug_3_slices_with_repeated_cluster_5.zip.ZIP.
# rm: cannot remove 'DataAugumentation.zip': No such file or directory
# rm: cannot remove 'data_aug_3_slices_with_repeated_cluster_5.zip': No such file or directory

# %%
# !unzip -qq '/content/data_aug(3_slices_with_repeated)_acceleration_full_data_20000.zip'

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
import joblib

SEQUENCE_LENGTH = 50
BATCH_SIZE = 45
EPOCHS = 250
LEARNING_RATE = 1e-5
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Data processing function
def process_file(file_path):
    df = pd.read_csv(file_path)

    df['Time'] = df['Time'] - df['Time'].iloc[0]

    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
    df['Acceleration'] = df['Speed'].diff().fillna(0)

    features = df[['Engine speed', 'Speed', 'slope', 'Acceleration']]
    target = df['Momentary fuel consumption']

    features = features.iloc[:SEQUENCE_LENGTH]
    target = target.iloc[:SEQUENCE_LENGTH]

    return features.values, target.values

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_original = []
y_original = []
X_augmented = []
y_augmented = []

base_folder_path = '/content/'

# Process the data
for i in range(6):
    if i == 5:
        folder_path = os.path.join(base_folder_path, f'data_aug(3_slices_with_repeated)_cluster_{i}')
        for filename in os.listdir(folder_path):
            if filename.endswith('.csv'):
                file_path = os.path.join(folder_path, filename)
                features, target = process_file(file_path)

                slices = filename.split('_')
                is_original_trip = slices[2] == slices[6] and slices[6] == slices[10]

                if is_original_trip:
                    X_original.append(features)
                    y_original.append(target)
                else:
                    X_augmented.append(features)
                    y_augmented.append(target)
# Out:
# cuda

# %%
# Function to pad or truncate sequences
def pad_or_truncate(sequence, length):
    if len(sequence) > length:
        return sequence[:length]
    elif len(sequence) < length:
        return np.pad(sequence, ((0, length - len(sequence)), (0, 0)), mode='constant')
    else:
        return sequence

# %%
# Apply padding/truncating to ensure consistent sequence length
X_original = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_original]
y_original = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_original]
X_augmented = [pad_or_truncate(x, SEQUENCE_LENGTH) for x in X_augmented]
y_augmented = [pad_or_truncate(y.reshape(-1, 1), SEQUENCE_LENGTH) for y in y_augmented]

# %%
# Convert data to PyTorch tensors
try:
    X_original = torch.tensor(np.array(X_original), dtype=torch.float32).to(DEVICE)
    y_original = torch.tensor(np.array(y_original), dtype=torch.float32).to(DEVICE)
    X_augmented = torch.tensor(np.array(X_augmented), dtype=torch.float32).to(DEVICE)
    y_augmented = torch.tensor(np.array(y_augmented), dtype=torch.float32).to(DEVICE)
except Exception as e:
    print(f"Error during tensor conversion: {e}")
    print(f"Shapes: X_original - {np.array(X_original).shape}, y_original - {np.array(y_original).shape}")
    print(f"Shapes: X_augmented - {np.array(X_augmented).shape}, y_augmented - {np.array(y_augmented).shape}")
    raise

# %%
# Split into training and test sets
# num_test = int(0.2 * len(X_original))
# X_test = X_original[:num_test]
# y_test = y_original[:num_test]
# X_train = torch.cat([X_original[num_test:], X_augmented])
# y_train = torch.cat([y_original[num_test:], y_augmented])


X_train = torch.cat([X_original, X_augmented])
y_train = torch.cat([y_original, y_augmented])
# X_train = X_original[num_test:]
# y_train = y_original[num_test:]

# %%
# Convert the min and max values to tensors
min_val_x = torch.tensor([0, 0, -10, -10], dtype=torch.float32).to(DEVICE)
max_val_x = torch.tensor([8000, 150, 10, 10], dtype=torch.float32).to(DEVICE)

min_val_y = torch.tensor([0], dtype=torch.float32).to(DEVICE)
max_val_y = torch.tensor([20000], dtype=torch.float32).to(DEVICE)

# Custom normalization function for X
def custom_normalize_X(data, min_vals, max_vals):
    for i in range(data.shape[-1]):
        data[:, :, i] = (data[:, :, i] - min_vals[i]) / (max_vals[i] - min_vals[i])
    return data

# Custom normalization function for y
def custom_normalize_y(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)

# Normalize X_train and X_test
X_train_normalized = custom_normalize_X(X_train, min_val_x, max_val_x)
# X_test_normalized = custom_normalize_X(X_test, min_val_x, max_val_x)

# Normalize y_train and y_test
y_train_normalized = custom_normalize_y(y_train, min_val_y, max_val_y)
# y_test_normalized = custom_normalize_y(y_test, min_val_y, max_val_y)

# %%
# Define the PyTorch model
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size,32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# %%
# Instantiate the model, define the loss function and the optimizer
model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
criterion = nn.L1Loss()
weight_decay = 1e-4  # L2 regularization factor
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=weight_decay)

# %%
# Assume 80% of the data is used for training and 20% for validation
train_size = int(0.8 * len(X_train_normalized))
val_size = len(X_train_normalized) - train_size

# Split the data while preserving the order
X_train_split = X_train_normalized[:train_size]
y_train_split = y_train_normalized[:train_size]

X_val_split = X_train_normalized[train_size:]
y_val_split = y_train_normalized[train_size:]



# BATCH_SIZE = 96
# # Create DataLoader for training and validation sets
# train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
# val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR  # Importing StepLR for learning rate decay

# Assuming `FuelConsumptionModel`, `X_train_normalized`, `train_loader`, `val_loader`, `DEVICE`, and `EPOCHS` are defined

# Choose a single loss function to use for all experiments
criterion = nn.L1Loss()  # You can change this to your preferred loss function

# Define weight decay values and initial learning rates for decay schedules
weight_decay_values = [1e-5]
initial_learning_rates = [1e-4]  # Two starting learning rates

# Initialize variables to track the best parameters
best_weight_decay = None
best_initial_lr = None
best_model_weights = None
best_val_loss = float('inf')

ini_batches = [64,96]
# Loop over all combinations of initial learning rates and weight decay values
for ini_batch in ini_batches:
    BATCH_SIZE = ini_batch
    # Create DataLoader for training and validation sets
    train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=BATCH_SIZE, shuffle=False)
    for wd in weight_decay_values:
        # Initialize model, criterion, and optimizer for each combination
        model = FuelConsumptionModel(input_size=X_train_normalized.shape[-1]).to(DEVICE)
        optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=wd)
        scheduler = StepLR(optimizer, step_size=50, gamma=0.5)  # Decay LR by 0.5 every 50 epochs

        # Early stopping parameters
        patience = 10  # Number of epochs to wait before stopping if no improvement
        best_loss = float('inf')  # Initialize best loss to infinity
        epochs_without_improvement = 0  # Counter for epochs without improvement

        # Training loop with early stopping
        model.train()
        for epoch in range(EPOCHS):
            running_loss = 0.0
            model.train()  # Ensure model is in training mode

            # Training phase
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

            # Calculate average loss for the epoch
            avg_training_loss = running_loss / len(train_loader)

            # Validation phase
            model.eval()  # Switch to evaluation mode
            val_running_loss = 0.0
            with torch.no_grad():
                for inputs, targets in val_loader:  # Assume you have a validation DataLoader `val_loader`
                    inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)  # Ensure data is on the correct device
                    outputs = model(inputs)
                    val_loss = criterion(outputs, targets)
                    val_running_loss += val_loss.item()

            avg_val_loss = val_running_loss / len(val_loader)

            current_lr = optimizer.param_groups[0]['lr']
            print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.4f} ---- Learning Rate: {current_lr:.2e}    Init LR: {init_lr:.0e}  batch: {BATCH_SIZE}")

            # print(f"Epoch [{epoch+1}/{EPOCHS}] ---- Training Loss: {avg_training_loss:.4f} ---- Validation Loss: {avg_val_loss:.4f}    Init LR: {init_lr:.0e}  WD: {wd:.0e}")

            # Adjust the learning rate
            scheduler.step()

            # Early stopping check
            if avg_val_loss < best_loss:
                best_loss = avg_val_loss
                epochs_without_improvement = 0
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    print(f"Early stopping at epoch {epoch+1}")
                    break

        # Save the model for the current combination
        model_filename = f'best_fuel_consumption_model_batch{BATCH_SIZE}_l50.pth'
        torch.save(model.state_dict(), model_filename)
        print(f"Saved model: {model_filename}")

        # Update best parameters based on validation loss
        if best_loss < best_val_loss:
            best_val_loss = best_loss
            best_weight_decay = wd
            best_initial_lr = init_lr
            best_model_weights = model.state_dict()  # Store the best model weights

# After all combinations, print the best initial learning rate and weight decay
print(f"Best Validation Loss: {best_val_loss:.4f}")
print(f"Best Initial Learning Rate: {best_initial_lr}")
print(f"Best Weight Decay: {best_weight_decay}")

# Save the best model weights
torch.save(best_model_weights, 'best_fuel_consumption_model_batch96.pth')
print("Best model saved as 'best_fuel_consumption_model_overall.pth'")
# Out:
# Epoch [1/250] ---- Training Loss: 0.0404 ---- Validation Loss: 0.0331 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [2/250] ---- Training Loss: 0.0336 ---- Validation Loss: 0.0295 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [3/250] ---- Training Loss: 0.0306 ---- Validation Loss: 0.0283 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [4/250] ---- Training Loss: 0.0292 ---- Validation Loss: 0.0272 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [5/250] ---- Training Loss: 0.0281 ---- Validation Loss: 0.0261 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [6/250] ---- Training Loss: 0.0270 ---- Validation Loss: 0.0249 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [7/250] ---- Training Loss: 0.0258 ---- Validation Loss: 0.0235 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [8/250] ---- Training Loss: 0.0246 ---- Validation Loss: 0.0221 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [9/250] ---- Training Loss: 0.0234 ---- Validation Loss: 0.0209 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [10/250] ---- Training Loss: 0.0224 ---- Validation Loss: 0.0201 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [11/250] ---- Training Loss: 0.0216 ---- Validation Loss: 0.0194 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [12/250] ---- Training Loss: 0.0210 ---- Validation Loss: 0.0189 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [13/250] ---- Training Loss: 0.0204 ---- Validation Loss: 0.0184 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [14/250] ---- Training Loss: 0.0199 ---- Validation Loss: 0.0178 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [15/250] ---- Training Loss: 0.0194 ---- Validation Loss: 0.0173 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [16/250] ---- Training Loss: 0.0189 ---- Validation Loss: 0.0168 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [17/250] ---- Training Loss: 0.0185 ---- Validation Loss: 0.0164 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [18/250] ---- Training Loss: 0.0181 ---- Validation Loss: 0.0161 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [19/250] ---- Training Loss: 0.0178 ---- Validation Loss: 0.0163 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [20/250] ---- Training Loss: 0.0176 ---- Validation Loss: 0.0157 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [21/250] ---- Training Loss: 0.0174 ---- Validation Loss: 0.0155 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [22/250] ---- Training Loss: 0.0172 ---- Validation Loss: 0.0154 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [23/250] ---- Training Loss: 0.0170 ---- Validation Loss: 0.0152 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [24/250] ---- Training Loss: 0.0169 ---- Validation Loss: 0.0151 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [25/250] ---- Training Loss: 0.0167 ---- Validation Loss: 0.0150 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [26/250] ---- Training Loss: 0.0165 ---- Validation Loss: 0.0148 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [27/250] ---- Training Loss: 0.0163 ---- Validation Loss: 0.0146 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [28/250] ---- Training Loss: 0.0162 ---- Validation Loss: 0.0145 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [29/250] ---- Training Loss: 0.0160 ---- Validation Loss: 0.0143 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [30/250] ---- Training Loss: 0.0159 ---- Validation Loss: 0.0142 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [31/250] ---- Training Loss: 0.0157 ---- Validation Loss: 0.0140 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [32/250] ---- Training Loss: 0.0155 ---- Validation Loss: 0.0138 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [33/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.0136 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [34/250] ---- Training Loss: 0.0152 ---- Validation Loss: 0.0134 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [35/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.0132 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [36/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.0131 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [37/250] ---- Training Loss: 0.0146 ---- Validation Loss: 0.0129 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [38/250] ---- Training Loss: 0.0144 ---- Validation Loss: 0.0127 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [39/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.0126 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [40/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.0125 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [41/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.0122 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [42/250] ---- Training Loss: 0.0138 ---- Validation Loss: 0.0120 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [43/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.0117 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [44/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.0116 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [45/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.0115 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [46/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.0113 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [47/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.0112 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [48/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.0110 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [49/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.0109 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [50/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.0108 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 64
# Epoch [51/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.0107 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [52/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.0107 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [53/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [54/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [55/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [56/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [57/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.0105 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [58/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.0104 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [59/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.0104 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [60/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [61/250] ---- Training Loss: 0.0121 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [62/250] ---- Training Loss: 0.0121 ---- Validation Loss: 0.0102 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [63/250] ---- Training Loss: 0.0120 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [64/250] ---- Training Loss: 0.0120 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [65/250] ---- Training Loss: 0.0120 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [66/250] ---- Training Loss: 0.0119 ---- Validation Loss: 0.0100 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [67/250] ---- Training Loss: 0.0118 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [68/250] ---- Training Loss: 0.0118 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [69/250] ---- Training Loss: 0.0118 ---- Validation Loss: 0.0099 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [70/250] ---- Training Loss: 0.0117 ---- Validation Loss: 0.0099 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [71/250] ---- Training Loss: 0.0117 ---- Validation Loss: 0.0098 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [72/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0097 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [73/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0097 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [74/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0099 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [75/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0097 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [76/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0096 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [77/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0096 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [78/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0095 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [79/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0095 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [80/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0095 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [81/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0094 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [82/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0094 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [83/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0093 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [84/250] ---- Training Loss: 0.0112 ---- Validation Loss: 0.0093 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [85/250] ---- Training Loss: 0.0112 ---- Validation Loss: 0.0093 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [86/250] ---- Training Loss: 0.0112 ---- Validation Loss: 0.0097 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [87/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [88/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0091 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [89/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0091 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [90/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [91/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [92/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0090 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [93/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0090 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [94/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0089 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [95/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0089 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [96/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [97/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [98/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [99/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0088 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [100/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 64
# Epoch [101/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0087 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [102/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0087 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [103/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [104/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [105/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [106/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0085 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [107/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [108/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [109/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [110/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [111/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [112/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0084 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [113/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [114/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [115/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [116/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [117/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0083 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [118/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0085 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [119/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0083 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [120/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0083 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [121/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0083 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [122/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0082 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [123/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0082 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [124/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0083 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [125/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0082 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [126/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0082 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [127/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0082 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [128/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0082 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [129/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0081 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [130/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0081 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [131/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0081 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [132/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0081 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [133/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0081 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [134/250] ---- Training Loss: 0.0102 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [135/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [136/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [137/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [138/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [139/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [140/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [141/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [142/250] ---- Training Loss: 0.0101 ---- Validation Loss: 0.0080 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [143/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [144/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [145/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [146/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [147/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [148/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0078 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [149/250] ---- Training Loss: 0.0100 ---- Validation Loss: 0.0079 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [150/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0078 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 64
# Epoch [151/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0078 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [152/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0078 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [153/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0078 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [154/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0078 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [155/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [156/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [157/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [158/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0078 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [159/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [160/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [161/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [162/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [163/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [164/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [165/250] ---- Training Loss: 0.0099 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [166/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [167/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [168/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [169/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [170/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [171/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [172/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [173/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [174/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0077 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [175/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [176/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [177/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [178/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [179/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [180/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [181/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [182/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [183/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [184/250] ---- Training Loss: 0.0098 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [185/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0076 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [186/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [187/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [188/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [189/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [190/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [191/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [192/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [193/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [194/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [195/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0074 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [196/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [197/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0075 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [198/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0074 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [199/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0074 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [200/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0074 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 64
# Epoch [201/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [202/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [203/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [204/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [205/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [206/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [207/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [208/250] ---- Training Loss: 0.0097 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [209/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [210/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [211/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [212/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [213/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [214/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [215/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [216/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [217/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [218/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [219/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [220/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [221/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [222/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [223/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [224/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [225/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [226/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [227/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [228/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0074 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [229/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [230/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [231/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [232/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [233/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [234/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [235/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [236/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [237/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [238/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [239/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [240/250] ---- Training Loss: 0.0096 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [241/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [242/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [243/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [244/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [245/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [246/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [247/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [248/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [249/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Epoch [250/250] ---- Training Loss: 0.0095 ---- Validation Loss: 0.0073 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 64
# Saved model: best_fuel_consumption_model_batch64_l50.pth
# Epoch [1/250] ---- Training Loss: 0.0399 ---- Validation Loss: 0.0339 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [2/250] ---- Training Loss: 0.0336 ---- Validation Loss: 0.0302 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [3/250] ---- Training Loss: 0.0310 ---- Validation Loss: 0.0290 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [4/250] ---- Training Loss: 0.0298 ---- Validation Loss: 0.0282 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [5/250] ---- Training Loss: 0.0289 ---- Validation Loss: 0.0273 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [6/250] ---- Training Loss: 0.0280 ---- Validation Loss: 0.0264 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [7/250] ---- Training Loss: 0.0272 ---- Validation Loss: 0.0255 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [8/250] ---- Training Loss: 0.0264 ---- Validation Loss: 0.0248 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [9/250] ---- Training Loss: 0.0257 ---- Validation Loss: 0.0239 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [10/250] ---- Training Loss: 0.0249 ---- Validation Loss: 0.0232 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [11/250] ---- Training Loss: 0.0241 ---- Validation Loss: 0.0221 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [12/250] ---- Training Loss: 0.0233 ---- Validation Loss: 0.0214 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [13/250] ---- Training Loss: 0.0226 ---- Validation Loss: 0.0207 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [14/250] ---- Training Loss: 0.0220 ---- Validation Loss: 0.0199 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [15/250] ---- Training Loss: 0.0213 ---- Validation Loss: 0.0192 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [16/250] ---- Training Loss: 0.0207 ---- Validation Loss: 0.0186 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [17/250] ---- Training Loss: 0.0202 ---- Validation Loss: 0.0182 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [18/250] ---- Training Loss: 0.0197 ---- Validation Loss: 0.0177 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [19/250] ---- Training Loss: 0.0194 ---- Validation Loss: 0.0174 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [20/250] ---- Training Loss: 0.0190 ---- Validation Loss: 0.0170 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [21/250] ---- Training Loss: 0.0187 ---- Validation Loss: 0.0168 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [22/250] ---- Training Loss: 0.0185 ---- Validation Loss: 0.0166 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [23/250] ---- Training Loss: 0.0182 ---- Validation Loss: 0.0164 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [24/250] ---- Training Loss: 0.0180 ---- Validation Loss: 0.0163 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [25/250] ---- Training Loss: 0.0179 ---- Validation Loss: 0.0162 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [26/250] ---- Training Loss: 0.0177 ---- Validation Loss: 0.0160 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [27/250] ---- Training Loss: 0.0176 ---- Validation Loss: 0.0161 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [28/250] ---- Training Loss: 0.0174 ---- Validation Loss: 0.0158 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [29/250] ---- Training Loss: 0.0173 ---- Validation Loss: 0.0156 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [30/250] ---- Training Loss: 0.0172 ---- Validation Loss: 0.0156 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [31/250] ---- Training Loss: 0.0170 ---- Validation Loss: 0.0155 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [32/250] ---- Training Loss: 0.0169 ---- Validation Loss: 0.0153 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [33/250] ---- Training Loss: 0.0167 ---- Validation Loss: 0.0150 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [34/250] ---- Training Loss: 0.0165 ---- Validation Loss: 0.0149 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [35/250] ---- Training Loss: 0.0163 ---- Validation Loss: 0.0147 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [36/250] ---- Training Loss: 0.0161 ---- Validation Loss: 0.0144 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [37/250] ---- Training Loss: 0.0158 ---- Validation Loss: 0.0141 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [38/250] ---- Training Loss: 0.0156 ---- Validation Loss: 0.0139 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [39/250] ---- Training Loss: 0.0154 ---- Validation Loss: 0.0135 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [40/250] ---- Training Loss: 0.0151 ---- Validation Loss: 0.0133 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [41/250] ---- Training Loss: 0.0149 ---- Validation Loss: 0.0131 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [42/250] ---- Training Loss: 0.0148 ---- Validation Loss: 0.0131 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [43/250] ---- Training Loss: 0.0146 ---- Validation Loss: 0.0131 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [44/250] ---- Training Loss: 0.0144 ---- Validation Loss: 0.0126 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [45/250] ---- Training Loss: 0.0142 ---- Validation Loss: 0.0125 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [46/250] ---- Training Loss: 0.0141 ---- Validation Loss: 0.0123 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [47/250] ---- Training Loss: 0.0140 ---- Validation Loss: 0.0122 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [48/250] ---- Training Loss: 0.0139 ---- Validation Loss: 0.0123 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [49/250] ---- Training Loss: 0.0137 ---- Validation Loss: 0.0119 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [50/250] ---- Training Loss: 0.0136 ---- Validation Loss: 0.0119 ---- Learning Rate: 1.00e-04    Init LR: 1e-04  batch: 96
# Epoch [51/250] ---- Training Loss: 0.0135 ---- Validation Loss: 0.0117 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [52/250] ---- Training Loss: 0.0134 ---- Validation Loss: 0.0116 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [53/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.0116 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [54/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.0115 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [55/250] ---- Training Loss: 0.0133 ---- Validation Loss: 0.0114 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [56/250] ---- Training Loss: 0.0132 ---- Validation Loss: 0.0115 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [57/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.0114 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [58/250] ---- Training Loss: 0.0131 ---- Validation Loss: 0.0114 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [59/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.0113 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [60/250] ---- Training Loss: 0.0130 ---- Validation Loss: 0.0112 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [61/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.0112 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [62/250] ---- Training Loss: 0.0129 ---- Validation Loss: 0.0111 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [63/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.0111 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [64/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.0110 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [65/250] ---- Training Loss: 0.0128 ---- Validation Loss: 0.0110 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [66/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.0109 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [67/250] ---- Training Loss: 0.0127 ---- Validation Loss: 0.0109 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [68/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.0109 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [69/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.0109 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [70/250] ---- Training Loss: 0.0126 ---- Validation Loss: 0.0109 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [71/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.0108 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [72/250] ---- Training Loss: 0.0125 ---- Validation Loss: 0.0108 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [73/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.0107 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [74/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.0107 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [75/250] ---- Training Loss: 0.0124 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [76/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [77/250] ---- Training Loss: 0.0123 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [78/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.0105 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [79/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.0104 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [80/250] ---- Training Loss: 0.0122 ---- Validation Loss: 0.0106 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [81/250] ---- Training Loss: 0.0121 ---- Validation Loss: 0.0104 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [82/250] ---- Training Loss: 0.0121 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [83/250] ---- Training Loss: 0.0121 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [84/250] ---- Training Loss: 0.0120 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [85/250] ---- Training Loss: 0.0120 ---- Validation Loss: 0.0103 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [86/250] ---- Training Loss: 0.0120 ---- Validation Loss: 0.0102 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [87/250] ---- Training Loss: 0.0119 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [88/250] ---- Training Loss: 0.0119 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [89/250] ---- Training Loss: 0.0119 ---- Validation Loss: 0.0101 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [90/250] ---- Training Loss: 0.0118 ---- Validation Loss: 0.0100 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [91/250] ---- Training Loss: 0.0118 ---- Validation Loss: 0.0100 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [92/250] ---- Training Loss: 0.0118 ---- Validation Loss: 0.0100 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [93/250] ---- Training Loss: 0.0117 ---- Validation Loss: 0.0100 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [94/250] ---- Training Loss: 0.0117 ---- Validation Loss: 0.0099 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [95/250] ---- Training Loss: 0.0117 ---- Validation Loss: 0.0099 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [96/250] ---- Training Loss: 0.0117 ---- Validation Loss: 0.0098 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [97/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0098 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [98/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0098 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [99/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0097 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [100/250] ---- Training Loss: 0.0116 ---- Validation Loss: 0.0097 ---- Learning Rate: 5.00e-05    Init LR: 1e-04  batch: 96
# Epoch [101/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0097 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [102/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0097 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [103/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [104/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [105/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [106/250] ---- Training Loss: 0.0115 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [107/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [108/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0095 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [109/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [110/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [111/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0095 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [112/250] ---- Training Loss: 0.0114 ---- Validation Loss: 0.0095 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [113/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0096 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [114/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0095 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [115/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0094 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [116/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0095 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [117/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0094 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [118/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0094 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [119/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0094 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [120/250] ---- Training Loss: 0.0113 ---- Validation Loss: 0.0093 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# ...
# Epoch [130/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [131/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [132/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [133/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [134/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [135/250] ---- Training Loss: 0.0111 ---- Validation Loss: 0.0092 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [136/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [137/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [138/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [139/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [140/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0091 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [141/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0090 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [142/250] ---- Training Loss: 0.0110 ---- Validation Loss: 0.0090 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [143/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0090 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [144/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0090 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [145/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0090 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [146/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0090 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [147/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0089 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [148/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0089 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [149/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0089 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [150/250] ---- Training Loss: 0.0109 ---- Validation Loss: 0.0089 ---- Learning Rate: 2.50e-05    Init LR: 1e-04  batch: 96
# Epoch [151/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0089 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [152/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0089 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [153/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0089 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [154/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0089 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [155/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0089 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [156/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [157/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [158/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [159/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [160/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [161/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [162/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [163/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [164/250] ---- Training Loss: 0.0108 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [165/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [166/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [167/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [168/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0088 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [169/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [170/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [171/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [172/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [173/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [174/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [175/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [176/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [177/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [178/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [179/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [180/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [181/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [182/250] ---- Training Loss: 0.0107 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [183/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [184/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [185/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0087 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [186/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [187/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [188/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [189/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [190/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [191/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [192/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [193/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [194/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [195/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [196/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0086 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [197/250] ---- Training Loss: 0.0106 ---- Validation Loss: 0.0085 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [198/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [199/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [200/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 1.25e-05    Init LR: 1e-04  batch: 96
# Epoch [201/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [202/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [203/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [204/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [205/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [206/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [207/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [208/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [209/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [210/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [211/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [212/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [213/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [214/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [215/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [216/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [217/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [218/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0085 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [219/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [220/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [221/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [222/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [223/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [224/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [225/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [226/250] ---- Training Loss: 0.0105 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [227/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [228/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [229/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [230/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [231/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [232/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [233/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [234/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [235/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [236/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [237/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [238/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [239/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [240/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [241/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [242/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [243/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [244/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [245/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [246/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [247/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0083 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [248/250] ---- Training Loss: 0.0103 ---- Validation Loss: 0.0083 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [249/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0084 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Epoch [250/250] ---- Training Loss: 0.0104 ---- Validation Loss: 0.0083 ---- Learning Rate: 6.25e-06    Init LR: 1e-04  batch: 96
# Saved model: best_fuel_consumption_model_batch96_l50.pth
# Best Validation Loss: 0.0073
# Best Initial Learning Rate: 0.0001
# Best Weight Decay: 1e-05
# Best model saved as 'best_fuel_consumption_model_overall.pth'

# %% [markdown]
# #test

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 600
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['Time'] - df['Time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip fuel consumption'] - df['Trip fuel consumption'].iloc[0]
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    features = df[['Engine speed', 'Speed', 'slope', 'Acceleration']]
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [8000, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values])
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title('Predicted vs Real Fuel Consumption')
    plt.legend()

    directory, filename = os.path.split(input_file)
    plot_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_predicted_vs_real.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV
    results_df = pd.DataFrame({
        'Speed': features["Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_predicted_vs_real.csv')
    results_df.to_csv(csv_filename, index=False)

# Paths to model and input file
model_path = '/content/best_fuel_consumption_model.pth'  # Adjust this to your PyTorch model path
input_file_path = '/content/NEDC_1000_slope_added.csv'

# Load model and predict
input_size = 4  # Number of features in the input data
model = load_trained_model(model_path, input_size)
plot_predicted_vs_real(input_file_path, model)

# %% [markdown]
# #Test with all saved model

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 600
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['Time'] - df['Time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip fuel consumption'] - df['Trip fuel consumption'].iloc[0]
    df['Acceleration'] = df['Speed'].diff().fillna(0)
    features = df[['Engine speed', 'Speed', 'slope', 'Acceleration']]
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [8000, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values])
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title('Predicted vs Real Fuel Consumption')
    plt.legend()

    # Save plot using model name
    directory, filename = os.path.split(input_file)
    plot_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_predicted_vs_real_{model_name}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name
    results_df = pd.DataFrame({
        'Speed': features["Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(directory, f'{os.path.splitext(filename)[0]}_predicted_vs_real_{model_name}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/NEDC_1000_slope_added.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model_batch96
# <ipython-input-34-ece2208f4053>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96.csv
# Testing model: best_fuel_consumption_model_batch96_l50
# <ipython-input-34-ece2208f4053>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96_l50.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96_l50.csv
# Testing model: best_fuel_consumption_model_batch64
# <ipython-input-34-ece2208f4053>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64.csv
# Testing model: best_fuel_consumption_model_batch96_l200
# <ipython-input-34-ece2208f4053>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv
# Testing model: best_fuel_consumption_model_batch64_l50
# <ipython-input-34-ece2208f4053>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64_l50.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64_l50.csv
# Testing model: best_fuel_consumption_model_batch64_l200
# <ipython-input-34-ece2208f4053>:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png
# CSV saved as: /content/NEDC_1000_slope_added_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn

# Constants
SEQUENCE_LENGTH = 600
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'  # Base directory to save plots and CSVs
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Ensure the base save directory exists
os.makedirs(PLOT_SAVE_DIR, exist_ok=True)

# Define the PyTorch model structure (same as the one used for training)
class FuelConsumptionModel(nn.Module):
    def __init__(self, input_size):
        super(FuelConsumptionModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 32, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(64, 32, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)
        self.dense = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x = self.dense(x)
        return x

# Load the trained model
def load_trained_model(model_path, input_size):
    model = FuelConsumptionModel(input_size=input_size)
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()
    return model

# Process the file and prepare segments
def process_file(file_path):
    df = pd.read_csv(file_path)
    df['Time'] = df['time'] - df['time'].iloc[0]
    df['Trip fuel consumption'] = df['Trip_fuel_consumption'] - df['Trip_fuel_consumption'].iloc[0]
    df['Acceleration'] = df['Vehicle_Speed'].diff().fillna(0)
    features = df[['Engine_speed', 'Vehicle_Speed', 'slope', 'Acceleration']]
    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)
    target = df['Momentary fuel consumption']
    return features, target

# Pad and normalize the data
def pad_and_normalize(data, sequence_length=SEQUENCE_LENGTH):
    padded_data = np.zeros((len(data), sequence_length, data[0].shape[1]))
    for i, seq in enumerate(data):
        length = min(len(seq), sequence_length)
        padded_data[i, :length] = seq[:length]

    # Normalization (same as in your script)
    min_val_x = [0, 0, -10, -10]
    max_val_x = [8000, 150, 10, 10]
    for i in range(padded_data.shape[-1]):
        padded_data[:, :, i] = (padded_data[:, :, i] - min_val_x[i]) / (max_val_x[i] - min_val_x[i])

    return torch.tensor(padded_data, dtype=torch.float32).to(DEVICE)

# Predict and plot the results
def plot_predicted_vs_real(input_file, model, model_name):
    features, actual_values = process_file(input_file)
    num_segments = len(features) // SEQUENCE_LENGTH
    predictions = []

    for i in range(num_segments):
        segment = features.iloc[i * SEQUENCE_LENGTH:(i + 1) * SEQUENCE_LENGTH]
        segment_normalized = pad_and_normalize([segment.values])
        with torch.no_grad():
            segment_predictions = model(segment_normalized).cpu().numpy()
        predictions.extend(segment_predictions.flatten() * 20000)

    # Handle any remaining data
    remainder = len(features) % SEQUENCE_LENGTH
    if remainder != 0:
        last_segment = features.iloc[-remainder:]
        last_segment_normalized = pad_and_normalize([last_segment.values])
        with torch.no_grad():
            last_segment_predictions = model(last_segment_normalized).cpu().numpy()
        predictions.extend(last_segment_predictions.flatten() * 20000)

    predictions = np.array(predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(actual_values.values[:len(predictions)], axis=0), label='Real', color='blue')
    plt.plot(np.cumsum(predictions[:len(actual_values)], axis=0), label='Predicted', color='red')
    plt.xlabel('Index')
    plt.ylabel('Fuel Consumption')
    plt.title(f'Predicted vs Real Fuel Consumption ({model_name})')
    plt.legend()

    # Create model-specific directory
    model_save_dir = os.path.join(PLOT_SAVE_DIR, model_name)
    os.makedirs(model_save_dir, exist_ok=True)

    # Save plot using model name in the designated directory
    plot_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}_predicted_vs_real_{model_name}.png')
    plt.savefig(plot_filename)
    plt.close()

    print(f"Plot saved as: {plot_filename}")

    # Save predictions and actual values to CSV using model name in the designated directory
    results_df = pd.DataFrame({
        'Speed': features["Vehicle_Speed"].iloc[:len(predictions)],
        'Actual': np.cumsum(actual_values.values[:len(predictions)], axis=0),
        'Predicted': np.cumsum(predictions[:len(actual_values)], axis=0)
    })

    csv_filename = os.path.join(model_save_dir, f'{os.path.splitext(os.path.basename(input_file))[0]}_predicted_vs_real_{model_name}.csv')
    results_df.to_csv(csv_filename, index=False)
    print(f"CSV saved as: {csv_filename}")

# Paths to input file and directory with models
input_file_path = '/content/output_file_56.csv'
model_dir = '/content/'  # Directory containing all saved models

# List all model files in the directory
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# Load and test each model
input_size = 4  # Number of features in the input data

for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    model_name = os.path.splitext(model_file)[0]  # Get the base name of the model file
    print(f"Testing model: {model_name}")

    model = load_trained_model(model_path, input_size)
    plot_predicted_vs_real(input_file_path, model, model_name)
# Out:
# Testing model: best_fuel_consumption_model_batch96
# <ipython-input-35-62071a34bcfc>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch96/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch96/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96.csv
# Testing model: best_fuel_consumption_model_batch96_l50
# <ipython-input-35-62071a34bcfc>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l50.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l50.csv
# Testing model: best_fuel_consumption_model_batch64
# <ipython-input-35-62071a34bcfc>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch64/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch64/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64.csv
# Testing model: best_fuel_consumption_model_batch96_l200
# <ipython-input-35-62071a34bcfc>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv
# Testing model: best_fuel_consumption_model_batch64_l50
# <ipython-input-35-62071a34bcfc>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l50.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l50.csv
# Testing model: best_fuel_consumption_model_batch64_l200
# <ipython-input-35-62071a34bcfc>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# Plot saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png
# CSV saved as: predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv

# %%
# !zip -r /content/predicted_vs_actual_plots.zip /content/predicted_vs_actual_plots
# Out:
#   adding: content/predicted_vs_actual_plots/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l50/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l50.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l50.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96_l200.csv (deflated 56%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l200.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l200/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l200.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64.png (deflated 9%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l50/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l50.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch64_l50/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch64_l50.png (deflated 8%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96/ (stored 0%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96.csv (deflated 55%)
#   adding: content/predicted_vs_actual_plots/best_fuel_consumption_model_batch96/output_file_56_predicted_vs_real_best_fuel_consumption_model_batch96.png (deflated 8%)

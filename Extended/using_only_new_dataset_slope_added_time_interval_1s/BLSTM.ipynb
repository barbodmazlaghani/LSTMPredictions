# %%
from google.colab import drive
drive.mount('/content/gdrive')


# !cp "/content/gdrive/My Drive/DataAugumentation.zip" .
#ADDED NEW SOURCE
# !cp "/content/gdrive/My Drive/data_aug(3_slices_with_repeated_slope_corrected_interval_1s)_cluster_5.zip" .
# !unzip -qq DataAugumentation.zip
# !unzip -qq data_aug_3_slices_with_repeated_cluster_5.zip
# !rm DataAugumentation.zip
# !rm data_aug(3_slices_with_repeated)_cluster_5.zip
data_path = 'DataAugumentation'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# unzip:  cannot find or open DataAugumentation.zip, DataAugumentation.zip.zip or DataAugumentation.zip.ZIP.
# unzip:  cannot find or open data_aug_3_slices_with_repeated_cluster_5.zip, data_aug_3_slices_with_repeated_cluster_5.zip.zip or data_aug_3_slices_with_repeated_cluster_5.zip.ZIP.
# rm: cannot remove 'DataAugumentation.zip': No such file or directory
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `rm data_aug(3_slices_with_repeated)_cluster_5.zip'

# %%
# !unzip -qq data_aug_3_slices_with_repeated_slope_corrected_interval_1s_cluster_5.zip

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import mean_squared_error
import joblib

SEQUENCE_LENGTH = 600
BATCH_SIZE = 64
EPOCHS = 50
LEARNING_RATE = 1e-4
PLOT_SAVE_DIR = 'predicted_vs_actual_plots'


def process_file(file_path):
    df = pd.read_csv(file_path)

    df['Time'] = df['Time'] - df['Time'].iloc[0]

    df['Momentary fuel consumption'] = df['Trip fuel consumption'].diff().fillna(0)

    # features = df[['Engine speed', 'Throttle position', 'Accelerator pedal position', 'Speed']]
    features = df[['Engine speed', 'Speed', 'slope']]
    target = df['Momentary fuel consumption']

    features = features.iloc[:SEQUENCE_LENGTH]
    target = target.iloc[:SEQUENCE_LENGTH]

    return features.values, target.values



def pad_and_normalize(data, scaler, sequence_length=SEQUENCE_LENGTH):
    padded_data = pad_sequences(data, maxlen=sequence_length, dtype='float32', padding='post', truncating='post')
    normalized_data = scaler.transform(padded_data.reshape(-1, padded_data.shape[-1])).reshape(padded_data.shape)
    return normalized_data


scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_original = []
y_original = []
X_augmented = []
y_augmented = []

base_folder_path = '/content/'

# CHANGED TO 6 FOR NEW DATA
for i in range(6):
  if i == 5 :
    folder_path = os.path.join(base_folder_path, f'data_aug(3_slices_with_repeated)_cluster_{i}')
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(folder_path, filename)
            features, target = process_file(file_path)

            slices = filename.split('_')
            is_original_trip = slices[0] == slices[2] and slices[0] == slices[4]

            if is_original_trip:
                X_original.append(features)
                y_original.append(target)
            else:
                X_augmented.append(features)
                y_augmented.append(target)

# Pad and convert lists to numpy arrays
# X_original = pad_sequences(X_original, maxlen=SEQUENCE_LENGTH, dtype='float32', padding='post', truncating='post')
# y_original = pad_sequences(y_original, maxlen=SEQUENCE_LENGTH, dtype='float32', padding='post', truncating='post')
X_augmented = pad_sequences(X_augmented, maxlen=SEQUENCE_LENGTH, dtype='float32', padding='post', truncating='post')
y_augmented = pad_sequences(y_augmented, maxlen=SEQUENCE_LENGTH, dtype='float32', padding='post', truncating='post')

num_test = int(0.05 * len(X_augmented))
X_test = X_augmented[:num_test]
y_test = y_augmented[:num_test]
X_train = X_augmented[num_test:]
y_train = y_augmented[num_test:]

scaler_X.fit(X_train.reshape(-1, X_train.shape[-1]))
scaler_y.fit(y_train.reshape(-1, 1))

joblib.dump(scaler_X, 'scaler_X.pkl')
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
print(X_augmented.shape)
# Out:
# (7789, 600, 3)

# %%
X_train_normalized = pad_and_normalize(X_train, scaler_X)
y_train_normalized = scaler_y.transform(y_train.reshape(-1, 1)).reshape(y_train.shape)
X_test_normalized = pad_and_normalize(X_test, scaler_X)
y_test_normalized = scaler_y.transform(y_test.reshape(-1, 1)).reshape(y_test.shape)

print('X_train_normalized shape:', X_train_normalized.shape)
print('y_train_normalized shape:', y_train_normalized.shape)
print('X_test_normalized shape:', X_test_normalized.shape)
print('y_test_normalized shape:', y_test_normalized.shape)
# Out:
# X_train_normalized shape: (7400, 600, 3)
# y_train_normalized shape: (7400, 600)
# X_test_normalized shape: (389, 600, 3)
# y_test_normalized shape: (389, 600)

# %%
model = Sequential([
    Bidirectional(LSTM(32, return_sequences=True, input_shape=(SEQUENCE_LENGTH, X_train_normalized.shape[-1]))),
    Dropout(0.2),
    Bidirectional(LSTM(32, return_sequences=True)),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss='mean_squared_error')

model.fit(X_train_normalized, y_train_normalized, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - loss: 0.0116 - val_loss: 0.0076
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 0.0087 - val_loss: 0.0074
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - loss: 0.0082 - val_loss: 0.0072
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 16s 71ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0075 - val_loss: 0.0068
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - loss: 0.0073 - val_loss: 0.0067
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 0.0070 - val_loss: 0.0064
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 81ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - loss: 0.0066 - val_loss: 0.0061
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 15s 127ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 88ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 28/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 105ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 13s 134ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 118ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 38/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - loss: 0.0048 - val_loss: 0.0044
# Epoch 44/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 46/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 91ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 50/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - loss: 0.0043 - val_loss: 0.0039

# %%
model.save('modelBLSTM_new_majid_added.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/My Drive/model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss = model.evaluate(X_test_normalized, y_test_normalized)
print(f"Test Loss: {test_loss}")

y_pred_normalized = model.predict(X_test_normalized)

y_test_inv = scaler_y.inverse_transform(y_test_normalized.reshape(-1, SEQUENCE_LENGTH))
y_pred_inv = scaler_y.inverse_transform(y_pred_normalized.reshape(-1, SEQUENCE_LENGTH))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0040
# Test Loss: 0.003908988554030657
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step

# %%
mse = mean_squared_error(y_test_inv, y_pred_inv)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 667094.75

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

if not os.path.exists(PLOT_SAVE_DIR):
    os.makedirs(PLOT_SAVE_DIR)

for i in range(len(X_test)):
    # Convert momentary to cumulative
    cumulative_actuals = np.cumsum(y_test_inv[i], axis=0)  # assuming y_test_inv is already the inverse transformed data
    cumulative_predictions = np.cumsum(y_pred_inv[i], axis=0)  # assuming y_pred_inv is already the inverse transformed predictions

    plt.figure(figsize=(12, 6))
    plt.plot(cumulative_actuals, label='Actual Trip Fuel Consumption')
    plt.plot(cumulative_predictions, label='Predicted Trip Fuel Consumption')
    plt.title(f'Trip {i + 1}: Actual vs Predicted Fuel Consumption')
    plt.xlabel('Time Steps')
    plt.ylabel('Trip Fuel Consumption (uL)')
    plt.legend()

    plot_filename = os.path.join(PLOT_SAVE_DIR, f'trip_{i + 1}_actual_vs_predicted.png')
    plt.savefig(plot_filename)
    plt.close()  # Close the plot to save memory

# %%
# !zip -r data.zip predicted_vs_actual_plots
# Out:
#   adding: predicted_vs_actual_plots/ (stored 0%)
#   adding: predicted_vs_actual_plots/trip_188_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_359_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_31_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_176_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_198_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_169_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_146_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_268_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_266_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_216_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_191_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_259_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_349_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_369_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_179_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_277_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_270_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_160_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_235_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_245_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_140_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_334_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_282_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_175_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_310_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_217_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_37_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_183_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_3_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_305_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_281_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_84_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_96_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_237_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_180_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_231_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_121_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_7_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_66_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_170_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_363_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_329_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_117_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_313_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_389_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_55_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_38_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_103_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_377_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_34_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_327_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_367_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_354_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_88_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_323_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_273_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_384_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_381_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_68_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_156_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip_126_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_142_actual_vs_predicted.png (deflated 9%)
#   adding: predicted_vs_actual_plots/trip_76_actual_vs_predicted.png (deflated 10%)
#   adding: predicted_vs_actual_plots/trip